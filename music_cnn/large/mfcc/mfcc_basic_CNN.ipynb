# %%
# https://medium.com/@imabhi1216/fine-tuning-a-pre-trained-resnet-18-model-for-image-classification-on-custom-dataset-with-pytorch-02df12e83c2c

# %%
import os
import shutil
from sklearn.model_selection import train_test_split
import random

import torch
import torchvision.models as models

from torchvision.datasets import ImageFolder
from torchvision.transforms import transforms
from torch.utils.data import Dataset, DataLoader

import time
from datetime import datetime
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix

import pandas as pd
import torch.nn.functional as F

from PIL import Image

from tqdm import tqdm

from itertools import product

# %%
def get_model():
    # Load the pre-trained ResNet-18 model
    model = models.resnet34(weights=models.ResNet34_Weights.DEFAULT)

    # Modify the last layer of the model
    num_classes = 2 # number of classes in dataset
    model.fc = torch.nn.Linear(model.fc.in_features, num_classes)
    return model

# %%
# Directory paths for the segments and lyrics
ai_segments_path = "/data/sg2121/fypdataset/dataset_large/normal_data/ai_segments"
human_segments_path = "/data/sg2121/fypdataset/dataset_large/normal_data/human"
ai_mfcc_path = "/data/sg2121/fypdataset/dataset_large/features/ai/MFCC"
human_mfcc_path = "/data/sg2121/fypdataset/dataset_large/features/human/MFCC"

# Helper function to read file paths from a text file
def read_file_paths(file_name):
    with open(file_name, 'r') as f:
        return [line.strip() for line in f.readlines()]

# Read all file paths from the text files
train_files = read_file_paths('/data/sg2121/aimusicdetector/train_test_split/train_files_large.txt')
val_files = read_file_paths('/data/sg2121/aimusicdetector/train_test_split/val_files_large.txt')
test_files = read_file_paths('/data/sg2121/aimusicdetector/train_test_split/test_files_large.txt')


# Function to convert segment file path to lyric file path
def convert_to_mfcc_path(file_path, is_ai):
    if is_ai:
        if file_path.startswith(ai_segments_path):
            base_mfcc_path = ai_mfcc_path
        else:
            return
    else:
        if file_path.startswith(human_segments_path):
            base_mfcc_path = human_mfcc_path
        else:
            return

    # Convert filename to mfcc filename
    file_name = os.path.basename(file_path).replace('.mp3', '-MFCC.png')
    return os.path.join(base_mfcc_path, file_name)


# Process the file lists and create tuples of (lyric_path, label)
def process_file_paths(file_paths, is_ai):
    return [(convert_to_mfcc_path(file_path, is_ai), 0 if is_ai else 1) for file_path in file_paths]

# Convert all file paths from the train, validation, and test sets
ai_train_files = process_file_paths(train_files, is_ai=True)
human_train_files = process_file_paths(train_files, is_ai=False)

ai_val_files = process_file_paths(val_files, is_ai=True)
human_val_files = process_file_paths(val_files, is_ai=False)

ai_test_files = process_file_paths(test_files, is_ai=True)
human_test_files = process_file_paths(test_files, is_ai=False)

def clean(paths):
    return [(p, l) for p, l in paths if p is not None]

train_files_combined = clean(ai_train_files) + clean(human_train_files)
val_files_combined = clean(ai_val_files) + clean(human_val_files)
test_files_combined = clean(ai_test_files) + clean(human_test_files)

# Shuffle the data if needed
random.shuffle(train_files_combined)
random.shuffle(val_files_combined)
random.shuffle(test_files_combined)

# Example of how you might check the splits
print(f"Training set size: {len(train_files_combined)}")
print(f"Validation set size: {len(val_files_combined)}")
print(f"Test set size: {len(test_files_combined)}")
# Out:
# Training set size: 15499
# Validation set size: 3321
# Test set size: 3324

# %%
# Custom dataset class
class MFCCDataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        path, label = self.data[idx]
        image = Image.open(path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        filename = os.path.basename(path)
        return image, label, filename
        
transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
# Create datasets
train_dataset = MFCCDataset(train_files_combined, transform=transform)
val_dataset = MFCCDataset(val_files_combined, transform=transform)
test_dataset = MFCCDataset(test_files_combined, transform=transform)

# DataLoaders
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Confirm sizes
print(f"Train set: {len(train_dataset)} samples")
print(f"Val set: {len(val_dataset)} samples")
print(f"Test set: {len(test_dataset)} samples")
# Out:
# Train set: 15499 samples
# Val set: 3321 samples
# Test set: 3324 samples

# %%
# Determine whether to use GPU (if available) or CPU
device = torch.device("mps" if torch.backends.mps.is_available() else "cuda" if torch.cuda.is_available() else "cpu")
print(device)

def train(model, train_loader, val_loader, criterion, optimizer, num_epochs):
    
    for epoch in range(num_epochs):
        # Set the model to training mode
        model.train()

        # Initialize running loss and correct predictions count for training
        running_loss = 0.0
        running_corrects = 0

        # Iterate over the training data loader
        for inputs, labels, filenames in train_loader:
            # Move inputs and labels to the device (GPU or CPU)
            inputs = inputs.to(device)
            labels = labels.to(device)

            # Reset the gradients to zero before the backward pass
            optimizer.zero_grad()

            # Forward pass: compute the model output
            outputs = model(inputs)
            # Get the predicted class (with the highest score)
            _, preds = torch.max(outputs, 1)
            # Compute the loss between the predictions and actual labels
            loss = criterion(outputs, labels)

            # Backward pass: compute gradients
            loss.backward()
            # Perform the optimization step to update model parameters
            optimizer.step()

            # Accumulate the running loss and the number of correct predictions
            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)

        # Compute average training loss and accuracy for this epoch
        train_loss = running_loss / len(train_loader.dataset)
        train_acc = running_corrects.float() / len(train_loader.dataset)

        # Set the model to evaluation mode for validation
        model.eval()
        # Initialize running loss and correct predictions count for validation
        running_loss = 0.0
        running_corrects = 0

        # Disable gradient computation for validation (saves memory and computations)
        with torch.no_grad():
            # Iterate over the validation data loader
            for inputs, labels, filenames in val_loader:
                # Move inputs and labels to the device (GPU or CPU)
                inputs = inputs.to(device)
                labels = labels.to(device)

                # Forward pass: compute the model output
                outputs = model(inputs)
                # Get the predicted class (with the highest score)
                _, preds = torch.max(outputs, 1)
                # Compute the loss between the predictions and actual labels
                loss = criterion(outputs, labels)

                # Accumulate the running loss and the number of correct predictions
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

        # Compute average validation loss and accuracy for this epoch
        val_loss = running_loss / len(val_loader.dataset)
        val_acc = running_corrects.float() / len(val_loader.dataset)

        # Print the results for the current epoch
        print(f'Epoch [{epoch+1}/{num_epochs}], train loss: {train_loss:.4f}, train acc: {train_acc:.4f}, val loss: {val_loss:.4f}, val acc: {val_acc:.4f}')
# Out:
# cuda

# %%
model = get_model()
model = model.to(device)

# Define the loss function and optimizer
lr = 0.001
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.fc.parameters(), lr, momentum=0.9)
num_epochs = 5

train(model, train_loader, val_loader, criterion, optimizer, num_epochs)
# Out:
# Epoch [1/5], train loss: 0.4834, train acc: 0.7613, val loss: 0.4321, val acc: 0.7952
# Epoch [2/5], train loss: 0.4396, train acc: 0.7951, val loss: 0.4600, val acc: 0.7952
# Epoch [3/5], train loss: 0.4406, train acc: 0.7924, val loss: 0.4167, val acc: 0.8154
# Epoch [4/5], train loss: 0.4309, train acc: 0.8015, val loss: 0.4354, val acc: 0.8064
# Epoch [5/5], train loss: 0.4232, train acc: 0.8038, val loss: 0.4095, val acc: 0.8211

# %%
def evaluate_model(model, test_loader, device, hyperparams=None):
    log_file = "/data/sg2121/aimusicdetector/music_cnn/large/mfcc/training_large_logfile.txt"

    model.eval()
    correct_pred = {classname: 0 for classname in ['ai', 'human']}
    total_pred = {classname: 0 for classname in ['ai', 'human']}

    all_labels = []
    all_preds = []
    
    start_time = time.time()

    with torch.no_grad():
        for inputs, labels, filenames in test_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            probs = F.softmax(outputs, dim=1)
            _, preds = torch.max(outputs, 1)

            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(preds.cpu().numpy())

            for label, prediction in zip(labels, preds):
                classname = 'ai' if label.item() == 0 else 'human'
                if label == prediction:
                    correct_pred[classname] += 1
                total_pred[classname] += 1

    end_time = time.time()
    avg_inference_time = (end_time - start_time) / len(test_loader.dataset)

    accuracy_per_class = {
        classname: correct_pred[classname] / total_pred[classname]
        if total_pred[classname] > 0 else 0
        for classname in ['ai', 'human']
    }

    overall_accuracy = accuracy_score(all_labels, all_preds)
    precision, recall, f1, _ = precision_recall_fscore_support(all_labels, all_preds, average=None, labels=[0, 1])
    cm = confusion_matrix(all_labels, all_preds)

    fpr = {}
    for i, classname in enumerate(['ai', 'human']):
        FP = cm[:, i].sum() - cm[i, i]
        TN = cm.sum() - (cm[i, :].sum() + cm[:, i].sum() - cm[i, i])
        fpr[classname] = FP / (FP + TN) if (FP + TN) > 0 else 0

    # Logging
    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    log_lines = [f"===== Evaluation at {timestamp} =====\n"]

    if hyperparams:
        log_lines.append("Hyperparameters:")
        for key, value in hyperparams.items():
            log_lines.append(f"{key}: {value}")
    else:
        log_lines.append("No hyperparameters provided.")
    log_lines.append("")

    log_lines.append("Accuracy per class:")
    for classname, acc in accuracy_per_class.items():
        log_lines.append(f"{classname}: {acc:.4f}")
    log_lines.append("\nPrecision, Recall, F1:")
    for i, classname in enumerate(['ai', 'human']):
        log_lines.append(f"{classname} → Precision: {precision[i]:.4f}, Recall: {recall[i]:.4f}, F1: {f1[i]:.4f}")
    log_lines.append("\nFalse Positive Rate:")
    for classname, rate in fpr.items():
        log_lines.append(f"{classname}: {rate:.4f}")
    log_lines.append(f"\nOverall Accuracy: {overall_accuracy:.4f}")
    log_lines.append(f"Average Inference Time per Sample: {avg_inference_time:.6f} seconds")
    log_lines.append("=" * 40 + "\n\n")

    print("\n".join(log_lines))
    with open(log_file, "a") as f:
        f.write("\n".join(log_lines))

    return overall_accuracy

# %%
model.eval()
results = []

for batch in tqdm(test_loader):
    inputs, labels, filenames = batch  # Unpack the filename from the dataset
    inputs = inputs.to(device)
    labels = labels.to(device)

    with torch.no_grad():
        outputs = model(inputs)
        probs = F.softmax(outputs, dim=1)

        for i in range(len(filenames)):
            results.append({
                "filename": filenames[i],  # Use filename directly from dataset
                "prob_ai": probs[i][0].item(),
                "prob_human": probs[i][1].item(),
                "true_label": labels[i].item(),
                "pred_label": torch.argmax(probs[i]).item()
            })

# Convert the results to a DataFrame
df = pd.DataFrame(results)

# Save to CSV
df.to_csv("mfcc_test_large_predictions.csv", index=False)

# Preview results
print(df.head())
# Out:
# 100%|███████████████████████████████████████| 104/104 [01:25<00:00,  1.22it/s]
#                      filename   prob_ai  prob_human  true_label  pred_label
# 0  S2057RN_segment_1-MFCC.png  0.970400    0.029600           0           0
# 1  S2641RN_segment_2-MFCC.png  0.987271    0.012729           0           0
# 2             H2137N-MFCC.png  0.097809    0.902191           1           1
# 3   S689RN_segment_2-MFCC.png  0.997355    0.002645           0           0
# 4  S4291RN_segment_2-MFCC.png  0.918202    0.081798           0           0

# %%
hyperparams = {
    "batch_size": batch_size,
    "learning_rate": lr,
    "epochs": num_epochs,
    "optimizer": optimizer,
    "model": model.__class__.__name__,
}

evaluate_model(model, test_loader, device, hyperparams=hyperparams)
# Out:
# ===== Evaluation at 2025-05-04 15:45:08 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.001
# epochs: 5
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 0
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.8502
# human: 0.7352
#
# Precision, Recall, F1:
# ai → Precision: 0.8502, Recall: 0.8502, F1: 0.8502
# human → Precision: 0.7352, Recall: 0.7352, F1: 0.7352
#
# False Positive Rate:
# ai: 0.2648
# human: 0.1498
#
# Overall Accuracy: 0.8087
# Average Inference Time per Sample: 0.025813 seconds
# ========================================
# 0.8086642599277978

# %%
# Define hyperparameter search space
learning_rates = [1e-3, 1e-4, 5e-4]
weight_decays = [1e-6, 1e-7, 1e-8]
epochs_list = [5, 10, 20] 

# Generate hyperparameter combinations and randomly select 10
param_combinations = list(product(learning_rates, weight_decays, epochs_list))
random.shuffle(param_combinations)
hyperparam_trials = param_combinations[:10]

# Run randomized search
best_model = None
best_acc = 0

for i, (lr, wd, epochs) in enumerate(hyperparam_trials):
    print(f"\n=== Trial {i+1}/10: LR={lr}, WD={wd}, Epochs={epochs} ===")

    model = get_model()
    model = model.to(device)
    
    # Use an optimizer like Adam or SGD (adjust based on your requirement)
    optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=0.9, weight_decay=wd)
    
    # Train the model (assuming you have a function to handle training)
    train(model, train_loader, val_loader, criterion, optimizer, epochs)

    hyperparams = {
        "batch_size": batch_size,
        "learning_rate": lr,
        "epochs": epochs,
        "optimizer": optimizer,
        "model": model.__class__.__name__,
    }
    
    val_acc = evaluate_model(model, val_loader, device, hyperparams=hyperparams)
    if val_acc > best_acc:
        best_acc = val_acc
        best_model = model
        torch.save(model.state_dict(), 'best_model.pt')
    
print("\nBest validation accuracy:", best_acc)
# Out:
# === Trial 1/10: LR=0.0001, WD=1e-06, Epochs=5 ===
# Epoch [1/5], train loss: 0.3993, train acc: 0.8159, val loss: 0.3150, val acc: 0.8570
# Epoch [2/5], train loss: 0.2898, train acc: 0.8708, val loss: 0.2867, val acc: 0.8723
# Epoch [3/5], train loss: 0.2484, train acc: 0.8909, val loss: 0.2643, val acc: 0.8868
# Epoch [4/5], train loss: 0.2209, train acc: 0.9080, val loss: 0.2768, val acc: 0.8814
# Epoch [5/5], train loss: 0.1878, train acc: 0.9221, val loss: 0.2611, val acc: 0.8886
# ===== Evaluation at 2025-05-04 23:33:31 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.0001
# epochs: 5
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.0001
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-06
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.8935
# human: 0.8799
#
# Precision, Recall, F1:
# ai → Precision: 0.9294, Recall: 0.8935, F1: 0.9111
# human → Precision: 0.8236, Recall: 0.8799, F1: 0.8508
#
# False Positive Rate:
# ai: 0.1201
# human: 0.1065
#
# Overall Accuracy: 0.8886
# Average Inference Time per Sample: 0.036340 seconds
# ========================================
#
#
#
# === Trial 2/10: LR=0.0005, WD=1e-06, Epochs=10 ===
# Epoch [1/10], train loss: 0.3395, train acc: 0.8416, val loss: 0.2618, val acc: 0.8859
# Epoch [2/10], train loss: 0.2431, train acc: 0.8924, val loss: 0.2465, val acc: 0.8922
# Epoch [3/10], train loss: 0.1901, train acc: 0.9188, val loss: 0.2722, val acc: 0.8856
# Epoch [4/10], train loss: 0.1446, train acc: 0.9405, val loss: 0.2551, val acc: 0.8994
# Epoch [5/10], train loss: 0.0966, train acc: 0.9618, val loss: 0.3505, val acc: 0.8889
# Epoch [6/10], train loss: 0.0843, train acc: 0.9670, val loss: 0.2856, val acc: 0.8952
# Epoch [7/10], train loss: 0.0598, train acc: 0.9780, val loss: 0.3700, val acc: 0.8774
# Epoch [8/10], train loss: 0.0447, train acc: 0.9837, val loss: 0.3384, val acc: 0.8916
# Epoch [9/10], train loss: 0.0314, train acc: 0.9892, val loss: 0.3587, val acc: 0.8937
# Epoch [10/10], train loss: 0.0369, train acc: 0.9868, val loss: 0.4429, val acc: 0.8919
# ===== Evaluation at 2025-05-05 01:30:38 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.0005
# epochs: 10
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.0005
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-06
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.9519
# human: 0.7857
#
# Precision, Recall, F1:
# ai → Precision: 0.8871, Recall: 0.9519, F1: 0.9184
# human → Precision: 0.9023, Recall: 0.7857, F1: 0.8399
#
# False Positive Rate:
# ai: 0.2143
# human: 0.0481
#
# Overall Accuracy: 0.8919
# Average Inference Time per Sample: 0.040737 seconds
# ========================================
#
#
#
# === Trial 3/10: LR=0.0005, WD=1e-08, Epochs=5 ===
# Epoch [1/5], train loss: 0.3342, train acc: 0.8413, val loss: 0.2766, val acc: 0.8771
# Epoch [2/5], train loss: 0.2411, train acc: 0.8925, val loss: 0.2557, val acc: 0.8904
# Epoch [3/5], train loss: 0.1846, train acc: 0.9223, val loss: 0.2798, val acc: 0.8726
# Epoch [4/5], train loss: 0.1555, train acc: 0.9346, val loss: 0.3120, val acc: 0.8708
# Epoch [5/5], train loss: 0.1145, train acc: 0.9541, val loss: 0.2598, val acc: 0.8961
# ===== Evaluation at 2025-05-05 02:30:52 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.0005
# epochs: 5
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.0005
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-08
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.9053
# human: 0.8799
#
# Precision, Recall, F1:
# ai → Precision: 0.9303, Recall: 0.9053, F1: 0.9176
# human → Precision: 0.8400, Recall: 0.8799, F1: 0.8595
#
# False Positive Rate:
# ai: 0.1201
# human: 0.0947
#
# Overall Accuracy: 0.8961
# Average Inference Time per Sample: 0.035908 seconds
# ========================================
#
#
#
# === Trial 4/10: LR=0.001, WD=1e-08, Epochs=10 ===
# Epoch [1/10], train loss: 0.3452, train acc: 0.8405, val loss: 0.2702, val acc: 0.8832
# Epoch [2/10], train loss: 0.2404, train acc: 0.8970, val loss: 0.2752, val acc: 0.8753
# Epoch [3/10], train loss: 0.1921, train acc: 0.9156, val loss: 0.2486, val acc: 0.8937
# Epoch [4/10], train loss: 0.1529, train acc: 0.9363, val loss: 0.3446, val acc: 0.8844
# Epoch [5/10], train loss: 0.1174, train acc: 0.9530, val loss: 0.3144, val acc: 0.8618
# Epoch [6/10], train loss: 0.0804, train acc: 0.9693, val loss: 0.3321, val acc: 0.8949
# Epoch [7/10], train loss: 0.0685, train acc: 0.9728, val loss: 0.4889, val acc: 0.8341
# Epoch [8/10], train loss: 0.0600, train acc: 0.9777, val loss: 0.3456, val acc: 0.9033
# Epoch [9/10], train loss: 0.0495, train acc: 0.9814, val loss: 0.3995, val acc: 0.8817
# Epoch [10/10], train loss: 0.0306, train acc: 0.9884, val loss: 0.4142, val acc: 0.8925
# ===== Evaluation at 2025-05-05 04:15:15 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.001
# epochs: 10
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-08
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.9402
# human: 0.8082
#
# Precision, Recall, F1:
# ai → Precision: 0.8966, Recall: 0.9402, F1: 0.9179
# human → Precision: 0.8841, Recall: 0.8082, F1: 0.8444
#
# False Positive Rate:
# ai: 0.1918
# human: 0.0598
#
# Overall Accuracy: 0.8925
# Average Inference Time per Sample: 0.026474 seconds
# ========================================
#
#
#
# === Trial 5/10: LR=0.0001, WD=1e-08, Epochs=20 ===
# Epoch [1/20], train loss: 0.4094, train acc: 0.8084, val loss: 0.3037, val acc: 0.8642
# Epoch [2/20], train loss: 0.2922, train acc: 0.8670, val loss: 0.2829, val acc: 0.8787
# Epoch [3/20], train loss: 0.2543, train acc: 0.8878, val loss: 0.2772, val acc: 0.8741
# Epoch [4/20], train loss: 0.2268, train acc: 0.9038, val loss: 0.2524, val acc: 0.8922
# Epoch [5/20], train loss: 0.1952, train acc: 0.9167, val loss: 0.2520, val acc: 0.8886
# Epoch [6/20], train loss: 0.1711, train acc: 0.9302, val loss: 0.2642, val acc: 0.8874
# Epoch [7/20], train loss: 0.1490, train acc: 0.9406, val loss: 0.2584, val acc: 0.8943
# Epoch [8/20], train loss: 0.1230, train acc: 0.9509, val loss: 0.2616, val acc: 0.8982
# Epoch [9/20], train loss: 0.1025, train acc: 0.9632, val loss: 0.2774, val acc: 0.8964
# Epoch [10/20], train loss: 0.0802, train acc: 0.9734, val loss: 0.2871, val acc: 0.8910
# Epoch [11/20], train loss: 0.0628, train acc: 0.9805, val loss: 0.3132, val acc: 0.8859
# Epoch [12/20], train loss: 0.0538, train acc: 0.9845, val loss: 0.3195, val acc: 0.8919
# Epoch [13/20], train loss: 0.0412, train acc: 0.9883, val loss: 0.3521, val acc: 0.8919
# Epoch [14/20], train loss: 0.0337, train acc: 0.9917, val loss: 0.3404, val acc: 0.8955
# Epoch [15/20], train loss: 0.0244, train acc: 0.9954, val loss: 0.3691, val acc: 0.8925
# Epoch [16/20], train loss: 0.0226, train acc: 0.9952, val loss: 0.3818, val acc: 0.8964
# Epoch [17/20], train loss: 0.0185, train acc: 0.9959, val loss: 0.3782, val acc: 0.8970
# Epoch [18/20], train loss: 0.0157, train acc: 0.9967, val loss: 0.3826, val acc: 0.8973
# Epoch [19/20], train loss: 0.0135, train acc: 0.9973, val loss: 0.3885, val acc: 0.8940
# Epoch [20/20], train loss: 0.0165, train acc: 0.9956, val loss: 0.3977, val acc: 0.8892
# ===== Evaluation at 2025-05-05 07:07:23 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.0001
# epochs: 20
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.0001
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-08
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.9251
# human: 0.8257
#
# Precision, Recall, F1:
# ai → Precision: 0.9038, Recall: 0.9251, F1: 0.9143
# human → Precision: 0.8616, Recall: 0.8257, F1: 0.8433
#
# False Positive Rate:
# ai: 0.1743
# human: 0.0749
#
# Overall Accuracy: 0.8892
# Average Inference Time per Sample: 0.034374 seconds
# ========================================
#
#
#
# === Trial 6/10: LR=0.001, WD=1e-06, Epochs=5 ===
# Epoch [1/5], train loss: 0.3264, train acc: 0.8486, val loss: 0.2521, val acc: 0.8907
# Epoch [2/5], train loss: 0.2359, train acc: 0.8981, val loss: 0.2864, val acc: 0.8790
# Epoch [3/5], train loss: 0.1925, train acc: 0.9139, val loss: 0.2393, val acc: 0.8919
# Epoch [4/5], train loss: 0.1455, train acc: 0.9379, val loss: 0.2771, val acc: 0.8874
# Epoch [5/5], train loss: 0.1213, train acc: 0.9513, val loss: 0.2525, val acc: 0.9024
# ===== Evaluation at 2025-05-05 08:06:31 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.001
# epochs: 5
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-06
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.9222
# human: 0.8674
#
# Precision, Recall, F1:
# ai → Precision: 0.9249, Recall: 0.9222, F1: 0.9235
# human → Precision: 0.8631, Recall: 0.8674, F1: 0.8652
#
# False Positive Rate:
# ai: 0.1326
# human: 0.0778
#
# Overall Accuracy: 0.9024
# Average Inference Time per Sample: 0.033896 seconds
# ========================================
#
#
#
# === Trial 7/10: LR=0.0005, WD=1e-08, Epochs=20 ===
# Epoch [1/20], train loss: 0.3449, train acc: 0.8415, val loss: 0.2962, val acc: 0.8633
# Epoch [2/20], train loss: 0.2462, train acc: 0.8891, val loss: 0.2572, val acc: 0.8859
# Epoch [3/20], train loss: 0.1911, train acc: 0.9186, val loss: 0.2576, val acc: 0.8868
# Epoch [4/20], train loss: 0.1497, train acc: 0.9400, val loss: 0.3064, val acc: 0.8844
# Epoch [5/20], train loss: 0.1110, train acc: 0.9546, val loss: 0.3298, val acc: 0.8862
# Epoch [6/20], train loss: 0.0825, train acc: 0.9679, val loss: 0.3767, val acc: 0.8838
# Epoch [7/20], train loss: 0.0607, train acc: 0.9785, val loss: 0.3664, val acc: 0.8952
# Epoch [8/20], train loss: 0.0546, train acc: 0.9806, val loss: 0.3974, val acc: 0.8759
# Epoch [9/20], train loss: 0.0424, train acc: 0.9850, val loss: 0.3776, val acc: 0.8886
# Epoch [10/20], train loss: 0.0351, train acc: 0.9881, val loss: 0.4035, val acc: 0.8970
# Epoch [11/20], train loss: 0.0333, train acc: 0.9886, val loss: 0.3978, val acc: 0.8856
# Epoch [12/20], train loss: 0.0226, train acc: 0.9930, val loss: 0.4089, val acc: 0.8835
# Epoch [13/20], train loss: 0.0206, train acc: 0.9928, val loss: 0.4687, val acc: 0.8928
# Epoch [14/20], train loss: 0.0184, train acc: 0.9932, val loss: 0.4411, val acc: 0.8967
# Epoch [15/20], train loss: 0.0200, train acc: 0.9923, val loss: 0.5060, val acc: 0.8814
# Epoch [16/20], train loss: 0.0185, train acc: 0.9939, val loss: 0.4742, val acc: 0.8940
# Epoch [17/20], train loss: 0.0147, train acc: 0.9950, val loss: 0.5763, val acc: 0.8717
# Epoch [18/20], train loss: 0.0124, train acc: 0.9957, val loss: 0.4792, val acc: 0.8790
# Epoch [19/20], train loss: 0.0124, train acc: 0.9958, val loss: 0.4927, val acc: 0.8973
# Epoch [20/20], train loss: 0.0087, train acc: 0.9973, val loss: 0.4741, val acc: 0.8964
# ===== Evaluation at 2025-05-05 12:03:03 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.0005
# epochs: 20
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.0005
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-08
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.9373
# human: 0.8240
#
# Precision, Recall, F1:
# ai → Precision: 0.9041, Recall: 0.9373, F1: 0.9204
# human → Precision: 0.8814, Recall: 0.8240, F1: 0.8517
#
# False Positive Rate:
# ai: 0.1760
# human: 0.0627
#
# Overall Accuracy: 0.8964
# Average Inference Time per Sample: 0.040261 seconds
# ========================================
#
#
#
# === Trial 8/10: LR=0.0005, WD=1e-06, Epochs=20 ===
# Epoch [1/20], train loss: 0.3440, train acc: 0.8378, val loss: 0.2825, val acc: 0.8699
# Epoch [2/20], train loss: 0.2454, train acc: 0.8912, val loss: 0.2815, val acc: 0.8645
# Epoch [3/20], train loss: 0.1986, train acc: 0.9126, val loss: 0.2660, val acc: 0.8871
# Epoch [4/20], train loss: 0.1433, train acc: 0.9395, val loss: 0.3334, val acc: 0.8823
# Epoch [5/20], train loss: 0.1044, train acc: 0.9604, val loss: 0.2817, val acc: 0.8940
# Epoch [6/20], train loss: 0.0838, train acc: 0.9679, val loss: 0.3056, val acc: 0.8931
# Epoch [7/20], train loss: 0.0574, train acc: 0.9791, val loss: 0.3339, val acc: 0.8910
# Epoch [8/20], train loss: 0.0454, train acc: 0.9837, val loss: 0.3729, val acc: 0.8913
# Epoch [9/20], train loss: 0.0419, train acc: 0.9852, val loss: 0.3506, val acc: 0.9009
# Epoch [10/20], train loss: 0.0334, train acc: 0.9879, val loss: 0.3984, val acc: 0.8925
# Epoch [11/20], train loss: 0.0190, train acc: 0.9940, val loss: 0.4355, val acc: 0.8943
# Epoch [12/20], train loss: 0.0213, train acc: 0.9928, val loss: 0.4178, val acc: 0.8940
# Epoch [13/20], train loss: 0.0083, train acc: 0.9981, val loss: 0.5229, val acc: 0.8988
# Epoch [14/20], train loss: 0.0130, train acc: 0.9955, val loss: 0.4666, val acc: 0.8943
# Epoch [15/20], train loss: 0.0164, train acc: 0.9935, val loss: 0.5329, val acc: 0.8919
# Epoch [16/20], train loss: 0.0120, train acc: 0.9954, val loss: 0.4612, val acc: 0.8904
# Epoch [17/20], train loss: 0.0097, train acc: 0.9971, val loss: 0.5671, val acc: 0.8708
# Epoch [18/20], train loss: 0.0115, train acc: 0.9959, val loss: 0.5038, val acc: 0.8940
# Epoch [19/20], train loss: 0.0072, train acc: 0.9978, val loss: 0.4433, val acc: 0.8988
# Epoch [20/20], train loss: 0.0048, train acc: 0.9986, val loss: 0.5053, val acc: 0.8997
# ===== Evaluation at 2025-05-05 16:21:57 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.0005
# epochs: 20
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.0005
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-06
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.9392
# human: 0.8299
#
# Precision, Recall, F1:
# ai → Precision: 0.9071, Recall: 0.9392, F1: 0.9229
# human → Precision: 0.8852, Recall: 0.8299, F1: 0.8567
#
# False Positive Rate:
# ai: 0.1701
# human: 0.0608
#
# Overall Accuracy: 0.8997
# Average Inference Time per Sample: 0.039078 seconds
# ========================================
#
#
#
# === Trial 9/10: LR=0.001, WD=1e-08, Epochs=20 ===
# Epoch [1/20], train loss: 0.3299, train acc: 0.8448, val loss: 0.2589, val acc: 0.8847
# Epoch [2/20], train loss: 0.2410, train acc: 0.8906, val loss: 0.2433, val acc: 0.8940
# Epoch [3/20], train loss: 0.1889, train acc: 0.9201, val loss: 0.2508, val acc: 0.8916
# Epoch [4/20], train loss: 0.1519, train acc: 0.9371, val loss: 0.2459, val acc: 0.9051
# Epoch [5/20], train loss: 0.1176, train acc: 0.9528, val loss: 0.3353, val acc: 0.8853
# Epoch [6/20], train loss: 0.0795, train acc: 0.9682, val loss: 0.3119, val acc: 0.9009
# Epoch [7/20], train loss: 0.0652, train acc: 0.9771, val loss: 0.3055, val acc: 0.9055
# Epoch [8/20], train loss: 0.0494, train acc: 0.9805, val loss: 0.3515, val acc: 0.8892
# Epoch [9/20], train loss: 0.0372, train acc: 0.9860, val loss: 0.4206, val acc: 0.8982
# Epoch [10/20], train loss: 0.0378, train acc: 0.9855, val loss: 0.4514, val acc: 0.8910
# Epoch [11/20], train loss: 0.0296, train acc: 0.9895, val loss: 0.4191, val acc: 0.8961
# Epoch [12/20], train loss: 0.0341, train acc: 0.9889, val loss: 0.4486, val acc: 0.8952
# Epoch [13/20], train loss: 0.0244, train acc: 0.9913, val loss: 0.5095, val acc: 0.8820
# Epoch [14/20], train loss: 0.0173, train acc: 0.9939, val loss: 0.5940, val acc: 0.8964
# Epoch [15/20], train loss: 0.0141, train acc: 0.9960, val loss: 0.4046, val acc: 0.9088
# Epoch [16/20], train loss: 0.0134, train acc: 0.9952, val loss: 0.4195, val acc: 0.9036
# Epoch [17/20], train loss: 0.0144, train acc: 0.9950, val loss: 0.4249, val acc: 0.9076
# Epoch [18/20], train loss: 0.0114, train acc: 0.9960, val loss: 0.4321, val acc: 0.8976
# Epoch [19/20], train loss: 0.0064, train acc: 0.9981, val loss: 0.4798, val acc: 0.9018
# Epoch [20/20], train loss: 0.0061, train acc: 0.9979, val loss: 0.4583, val acc: 0.9079
# ===== Evaluation at 2025-05-05 18:46:11 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.001
# epochs: 20
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-08
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.9397
# human: 0.8515
#
# Precision, Recall, F1:
# ai → Precision: 0.9180, Recall: 0.9397, F1: 0.9287
# human → Precision: 0.8886, Recall: 0.8515, F1: 0.8697
#
# False Positive Rate:
# ai: 0.1485
# human: 0.0603
#
# Overall Accuracy: 0.9079
# Average Inference Time per Sample: 0.020808 seconds
# ========================================
#
#
#
# === Trial 10/10: LR=0.001, WD=1e-08, Epochs=5 ===
# Epoch [1/5], train loss: 0.3233, train acc: 0.8516, val loss: 0.2778, val acc: 0.8756
# Epoch [2/5], train loss: 0.2326, train acc: 0.8992, val loss: 0.2485, val acc: 0.8886
# Epoch [3/5], train loss: 0.1847, train acc: 0.9210, val loss: 0.2677, val acc: 0.8973
# Epoch [4/5], train loss: 0.1453, train acc: 0.9401, val loss: 0.2629, val acc: 0.8916
# Epoch [5/5], train loss: 0.1099, train acc: 0.9546, val loss: 0.3133, val acc: 0.8850
# ===== Evaluation at 2025-05-05 19:21:02 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.001
# epochs: 5
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-08
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.9222
# human: 0.8190
#
# Precision, Recall, F1:
# ai → Precision: 0.9002, Recall: 0.9222, F1: 0.9111
# human → Precision: 0.8561, Recall: 0.8190, F1: 0.8372
#
# False Positive Rate:
# ai: 0.1810
# human: 0.0778
#
# Overall Accuracy: 0.8850
# Average Inference Time per Sample: 0.020178 seconds
# ========================================
#
#
#
# Best validation accuracy: 0.907859078590786
