# %%
# https://medium.com/@imabhi1216/fine-tuning-a-pre-trained-resnet-18-model-for-image-classification-on-custom-dataset-with-pytorch-02df12e83c2c

# %%
import os
import shutil
from sklearn.model_selection import train_test_split
import random

import torch
import torchvision.models as models

from torchvision.datasets import ImageFolder
from torchvision.transforms import transforms
from torch.utils.data import Dataset, DataLoader

import time
from datetime import datetime
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix

import pandas as pd
import torch.nn.functional as F

from PIL import Image

from tqdm import tqdm

from itertools import product

# %%
def get_model():
    # Load the pre-trained ResNet-18 model
    model = models.resnet34(weights=models.ResNet34_Weights.DEFAULT)

    # Modify the last layer of the model
    num_classes = 2 # number of classes in dataset
    model.fc = torch.nn.Linear(model.fc.in_features, num_classes)
    return model

# %%
# Directory paths for the segments and lyrics
ai_segments_path = "/data/sg2121/fypdataset/dataset_large/normal_data/ai_segments"
human_segments_path = "/data/sg2121/fypdataset/dataset_large/normal_data/human"
ai_cqt_path = "/data/sg2121/fypdataset/dataset_large/features/ai/CQT"
human_cqt_path = "/data/sg2121/fypdataset/dataset_large/features/human/CQT"

# Helper function to read file paths from a text file
def read_file_paths(file_name):
    with open(file_name, 'r') as f:
        return [line.strip() for line in f.readlines()]

# Read all file paths from the text files
train_files = read_file_paths('/data/sg2121/aimusicdetector/train_test_split/train_files_large.txt')
val_files = read_file_paths('/data/sg2121/aimusicdetector/train_test_split/val_files_large.txt')
test_files = read_file_paths('/data/sg2121/aimusicdetector/train_test_split/test_files_large.txt')


# Function to convert segment file path to lyric file path
def convert_to_cqt_path(file_path, is_ai):
    if is_ai:
        if file_path.startswith(ai_segments_path):
            base_cqt_path = ai_cqt_path
        else:
            return
    else:
        if file_path.startswith(human_segments_path):
            base_cqt_path = human_cqt_path
        else:
            return

    # Convert filename to cqt filename
    file_name = os.path.basename(file_path).replace('.mp3', '-CQT.png')
    return os.path.join(base_cqt_path, file_name)


# Process the file lists and create tuples of (lyric_path, label)
def process_file_paths(file_paths, is_ai):
    return [(convert_to_cqt_path(file_path, is_ai), 0 if is_ai else 1) for file_path in file_paths]

# Convert all file paths from the train, validation, and test sets
ai_train_files = process_file_paths(train_files, is_ai=True)
human_train_files = process_file_paths(train_files, is_ai=False)

ai_val_files = process_file_paths(val_files, is_ai=True)
human_val_files = process_file_paths(val_files, is_ai=False)

ai_test_files = process_file_paths(test_files, is_ai=True)
human_test_files = process_file_paths(test_files, is_ai=False)

def clean(paths):
    return [(p, l) for p, l in paths if p is not None]

train_files_combined = clean(ai_train_files) + clean(human_train_files)
val_files_combined = clean(ai_val_files) + clean(human_val_files)
test_files_combined = clean(ai_test_files) + clean(human_test_files)

# Shuffle the data if needed
random.shuffle(train_files_combined)
random.shuffle(val_files_combined)
random.shuffle(test_files_combined)

# Example of how you might check the splits
print(f"Training set size: {len(train_files_combined)}")
print(f"Validation set size: {len(val_files_combined)}")
print(f"Test set size: {len(test_files_combined)}")
# Out:
# Training set size: 15499
# Validation set size: 3321
# Test set size: 3324

# %%
# Custom dataset class
class CQTSpectrogramDataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        path, label = self.data[idx]
        image = Image.open(path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        filename = os.path.basename(path)
        return image, label, filename
        
transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
# Create datasets
train_dataset = CQTSpectrogramDataset(train_files_combined, transform=transform)
val_dataset = CQTSpectrogramDataset(val_files_combined, transform=transform)
test_dataset = CQTSpectrogramDataset(test_files_combined, transform=transform)

# DataLoaders
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Confirm sizes
print(f"Train set: {len(train_dataset)} samples")
print(f"Val set: {len(val_dataset)} samples")
print(f"Test set: {len(test_dataset)} samples")
# Out:
# Train set: 15499 samples
# Val set: 3321 samples
# Test set: 3324 samples

# %%
# Determine whether to use GPU (if available) or CPU
device = torch.device("mps" if torch.backends.mps.is_available() else "cuda" if torch.cuda.is_available() else "cpu")
print(device)

def train(model, train_loader, val_loader, criterion, optimizer, num_epochs):
    
    for epoch in range(num_epochs):
        # Set the model to training mode
        model.train()

        # Initialize running loss and correct predictions count for training
        running_loss = 0.0
        running_corrects = 0

        # Iterate over the training data loader
        for inputs, labels, filenames in train_loader:
            # Move inputs and labels to the device (GPU or CPU)
            inputs = inputs.to(device)
            labels = labels.to(device)

            # Reset the gradients to zero before the backward pass
            optimizer.zero_grad()

            # Forward pass: compute the model output
            outputs = model(inputs)
            # Get the predicted class (with the highest score)
            _, preds = torch.max(outputs, 1)
            # Compute the loss between the predictions and actual labels
            loss = criterion(outputs, labels)

            # Backward pass: compute gradients
            loss.backward()
            # Perform the optimization step to update model parameters
            optimizer.step()

            # Accumulate the running loss and the number of correct predictions
            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)

        # Compute average training loss and accuracy for this epoch
        train_loss = running_loss / len(train_loader.dataset)
        train_acc = running_corrects.float() / len(train_loader.dataset)

        # Set the model to evaluation mode for validation
        model.eval()
        # Initialize running loss and correct predictions count for validation
        running_loss = 0.0
        running_corrects = 0

        # Disable gradient computation for validation (saves memory and computations)
        with torch.no_grad():
            # Iterate over the validation data loader
            for inputs, labels, filenames in val_loader:
                # Move inputs and labels to the device (GPU or CPU)
                inputs = inputs.to(device)
                labels = labels.to(device)

                # Forward pass: compute the model output
                outputs = model(inputs)
                # Get the predicted class (with the highest score)
                _, preds = torch.max(outputs, 1)
                # Compute the loss between the predictions and actual labels
                loss = criterion(outputs, labels)

                # Accumulate the running loss and the number of correct predictions
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

        # Compute average validation loss and accuracy for this epoch
        val_loss = running_loss / len(val_loader.dataset)
        val_acc = running_corrects.float() / len(val_loader.dataset)

        # Print the results for the current epoch
        print(f'Epoch [{epoch+1}/{num_epochs}], train loss: {train_loss:.4f}, train acc: {train_acc:.4f}, val loss: {val_loss:.4f}, val acc: {val_acc:.4f}')
# Out:
# cuda

# %%
model = get_model()
model = model.to(device)

# Define the loss function and optimizer
lr = 0.001
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.fc.parameters(), lr, momentum=0.9)
num_epochs = 5

train(model, train_loader, val_loader, criterion, optimizer, num_epochs)
# Out:
# Epoch [1/5], train loss: 0.5279, train acc: 0.7322, val loss: 0.4814, val acc: 0.7660
# Epoch [2/5], train loss: 0.4883, train acc: 0.7601, val loss: 0.4710, val acc: 0.7742
# Epoch [3/5], train loss: 0.4786, train acc: 0.7662, val loss: 0.4760, val acc: 0.7702
# Epoch [4/5], train loss: 0.4814, train acc: 0.7658, val loss: 0.4720, val acc: 0.7706
# Epoch [5/5], train loss: 0.4705, train acc: 0.7704, val loss: 0.4683, val acc: 0.7754

# %%
def evaluate_model(model, test_loader, device, hyperparams=None):
    log_file = "/data/sg2121/aimusicdetector/music_cnn/large/cqt/training_large_logfile.txt"

    model.eval()
    correct_pred = {classname: 0 for classname in ['ai', 'human']}
    total_pred = {classname: 0 for classname in ['ai', 'human']}

    all_labels = []
    all_preds = []
    
    start_time = time.time()

    with torch.no_grad():
        for inputs, labels, filenames in test_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            probs = F.softmax(outputs, dim=1)
            _, preds = torch.max(outputs, 1)

            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(preds.cpu().numpy())

            for label, prediction in zip(labels, preds):
                classname = 'ai' if label.item() == 0 else 'human'
                if label == prediction:
                    correct_pred[classname] += 1
                total_pred[classname] += 1

    end_time = time.time()
    avg_inference_time = (end_time - start_time) / len(test_loader.dataset)

    accuracy_per_class = {
        classname: correct_pred[classname] / total_pred[classname]
        if total_pred[classname] > 0 else 0
        for classname in ['ai', 'human']
    }

    overall_accuracy = accuracy_score(all_labels, all_preds)
    precision, recall, f1, _ = precision_recall_fscore_support(all_labels, all_preds, average=None, labels=[0, 1])
    cm = confusion_matrix(all_labels, all_preds)

    fpr = {}
    for i, classname in enumerate(['ai', 'human']):
        FP = cm[:, i].sum() - cm[i, i]
        TN = cm.sum() - (cm[i, :].sum() + cm[:, i].sum() - cm[i, i])
        fpr[classname] = FP / (FP + TN) if (FP + TN) > 0 else 0

    # Logging
    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    log_lines = [f"===== Evaluation at {timestamp} =====\n"]

    if hyperparams:
        log_lines.append("Hyperparameters:")
        for key, value in hyperparams.items():
            log_lines.append(f"{key}: {value}")
    else:
        log_lines.append("No hyperparameters provided.")
    log_lines.append("")

    log_lines.append("Accuracy per class:")
    for classname, acc in accuracy_per_class.items():
        log_lines.append(f"{classname}: {acc:.4f}")
    log_lines.append("\nPrecision, Recall, F1:")
    for i, classname in enumerate(['ai', 'human']):
        log_lines.append(f"{classname} → Precision: {precision[i]:.4f}, Recall: {recall[i]:.4f}, F1: {f1[i]:.4f}")
    log_lines.append("\nFalse Positive Rate:")
    for classname, rate in fpr.items():
        log_lines.append(f"{classname}: {rate:.4f}")
    log_lines.append(f"\nOverall Accuracy: {overall_accuracy:.4f}")
    log_lines.append(f"Average Inference Time per Sample: {avg_inference_time:.6f} seconds")
    log_lines.append("=" * 40 + "\n\n")

    print("\n".join(log_lines))
    with open(log_file, "a") as f:
        f.write("\n".join(log_lines))

    return overall_accuracy

# %%
model.eval()
results = []

for batch in tqdm(test_loader):
    inputs, labels, filenames = batch  # Unpack the filename from the dataset
    inputs = inputs.to(device)
    labels = labels.to(device)

    with torch.no_grad():
        outputs = model(inputs)
        probs = F.softmax(outputs, dim=1)

        for i in range(len(filenames)):
            results.append({
                "filename": filenames[i],  # Use filename directly from dataset
                "prob_ai": probs[i][0].item(),
                "prob_human": probs[i][1].item(),
                "true_label": labels[i].item(),
                "pred_label": torch.argmax(probs[i]).item()
            })

# Convert the results to a DataFrame
df = pd.DataFrame(results)

# Save to CSV
df.to_csv("cqt_test_large_predictions.csv", index=False)

# Preview results
print(df.head())
# Out:
# 100%|███████████████████████████████████████| 104/104 [00:47<00:00,  2.17it/s]
#                     filename   prob_ai  prob_human  true_label  pred_label
# 0  S2576RN_segment_2-CQT.png  0.837007    0.162993           0           0
# 1             H2343N-CQT.png  0.222715    0.777285           1           1
# 2  S1949RN_segment_1-CQT.png  0.860536    0.139464           0           0
# 3  U1796RN_segment_1-CQT.png  0.112601    0.887399           0           1
# 4  S4413RN_segment_2-CQT.png  0.963230    0.036770           0           0

# %%
hyperparams = {
    "batch_size": batch_size,
    "learning_rate": lr,
    "epochs": num_epochs,
    "optimizer": optimizer,
    "model": model.__class__.__name__,
}

evaluate_model(model, test_loader, device, hyperparams=hyperparams)
# Out:
# ===== Evaluation at 2025-05-04 15:47:35 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.001
# epochs: 5
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 0
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.8846
# human: 0.6012
#
# Precision, Recall, F1:
# ai → Precision: 0.7968, Recall: 0.8846, F1: 0.8384
# human → Precision: 0.7466, Recall: 0.6012, F1: 0.6661
#
# False Positive Rate:
# ai: 0.3988
# human: 0.1154
#
# Overall Accuracy: 0.7822
# Average Inference Time per Sample: 0.016211 seconds
# ========================================
# 0.7821901323706378

# %%
# Define hyperparameter search space
learning_rates = [1e-3, 1e-4, 5e-4]
weight_decays = [1e-6, 1e-7, 1e-8]
epochs_list = [5, 10, 20] 

# Generate hyperparameter combinations and randomly select 10
param_combinations = list(product(learning_rates, weight_decays, epochs_list))
random.shuffle(param_combinations)
hyperparam_trials = param_combinations[:10]

# Run randomized search
best_model = None
best_acc = 0

for i, (lr, wd, epochs) in enumerate(hyperparam_trials):
    print(f"\n=== Trial {i+1}/10: LR={lr}, WD={wd}, Epochs={epochs} ===")

    model = get_model()
    model = model.to(device)
    
    # Use an optimizer like Adam or SGD (adjust based on your requirement)
    optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=0.9, weight_decay=wd)
    
    # Train the model (assuming you have a function to handle training)
    train(model, train_loader, val_loader, criterion, optimizer, epochs)

    hyperparams = {
        "batch_size": batch_size,
        "learning_rate": lr,
        "epochs": epochs,
        "optimizer": optimizer,
        "model": model.__class__.__name__,
    }
    
    val_acc = evaluate_model(model, val_loader, device, hyperparams=hyperparams)
    if val_acc > best_acc:
        best_acc = val_acc
        best_model = model
        torch.save(model.state_dict(), 'best_model.pt')
    
print("\nBest validation accuracy:", best_acc)
# Out:
# === Trial 1/10: LR=0.001, WD=1e-08, Epochs=5 ===
# Epoch [1/5], train loss: 0.3701, train acc: 0.8243, val loss: 0.3389, val acc: 0.8443
# Epoch [2/5], train loss: 0.2575, train acc: 0.8837, val loss: 0.3090, val acc: 0.8687
# Epoch [3/5], train loss: 0.1803, train acc: 0.9258, val loss: 0.3164, val acc: 0.8708
# Epoch [4/5], train loss: 0.1000, train acc: 0.9603, val loss: 0.3890, val acc: 0.8506
# Epoch [5/5], train loss: 0.0699, train acc: 0.9743, val loss: 0.5272, val acc: 0.8561
# ===== Evaluation at 2025-05-04 23:32:53 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.001
# epochs: 5
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-08
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.9298
# human: 0.7256
#
# Precision, Recall, F1:
# ai → Precision: 0.8571, Recall: 0.9298, F1: 0.8920
# human → Precision: 0.8538, Recall: 0.7256, F1: 0.7845
#
# False Positive Rate:
# ai: 0.2744
# human: 0.0702
#
# Overall Accuracy: 0.8561
# Average Inference Time per Sample: 0.034069 seconds
# ========================================
#
#
#
# === Trial 2/10: LR=0.0001, WD=1e-08, Epochs=20 ===
# Epoch [1/20], train loss: 0.4870, train acc: 0.7553, val loss: 0.3733, val acc: 0.8284
# Epoch [13/20], train loss: 0.0141, train acc: 0.9948, val loss: 0.5911, val acc: 0.8696
# Epoch [14/20], train loss: 0.0177, train acc: 0.9937, val loss: 0.5821, val acc: 0.8705
# Epoch [15/20], train loss: 0.0104, train acc: 0.9966, val loss: 0.6249, val acc: 0.8771
# Epoch [16/20], train loss: 0.0136, train acc: 0.9954, val loss: 0.5881, val acc: 0.8759
# Epoch [17/20], train loss: 0.0072, train acc: 0.9975, val loss: 0.6647, val acc: 0.8603
# Epoch [18/20], train loss: 0.0054, train acc: 0.9981, val loss: 0.7203, val acc: 0.8759
# Epoch [19/20], train loss: 0.0076, train acc: 0.9975, val loss: 0.6511, val acc: 0.8762
# Epoch [20/20], train loss: 0.0041, train acc: 0.9986, val loss: 0.7069, val acc: 0.8799
# ===== Evaluation at 2025-05-05 09:39:06 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.001
# epochs: 20
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-08
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.9246
# human: 0.8007
#
# Precision, Recall, F1:
# ai → Precision: 0.8914, Recall: 0.9246, F1: 0.9077
# human → Precision: 0.8571, Recall: 0.8007, F1: 0.8279
#
# False Positive Rate:
# ai: 0.1993
# human: 0.0754
#
# Overall Accuracy: 0.8799
# Average Inference Time per Sample: 0.040102 seconds
# ========================================
#
#
#
# === Trial 5/10: LR=0.0005, WD=1e-06, Epochs=10 ===
# Epoch [1/10], train loss: 0.3924, train acc: 0.8136, val loss: 0.3204, val acc: 0.8531
# Epoch [2/10], train loss: 0.2737, train acc: 0.8788, val loss: 0.2912, val acc: 0.8675
# Epoch [3/10], train loss: 0.1922, train acc: 0.9183, val loss: 0.3129, val acc: 0.8660
# Epoch [4/10], train loss: 0.1097, train acc: 0.9599, val loss: 0.3919, val acc: 0.8549
# Epoch [5/10], train loss: 0.0557, train acc: 0.9808, val loss: 0.4267, val acc: 0.8687
# Epoch [6/10], train loss: 0.0360, train acc: 0.9892, val loss: 0.5007, val acc: 0.8672
# Epoch [7/10], train loss: 0.0368, train acc: 0.9875, val loss: 0.4903, val acc: 0.8567
# Epoch [8/10], train loss: 0.0403, train acc: 0.9848, val loss: 0.5296, val acc: 0.8603
# Epoch [9/10], train loss: 0.0236, train acc: 0.9920, val loss: 0.5493, val acc: 0.8621
# Epoch [10/10], train loss: 0.0215, train acc: 0.9928, val loss: 0.5615, val acc: 0.8645
# ===== Evaluation at 2025-05-05 11:48:27 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.0005
# epochs: 10
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.0005
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-06
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.8992
# human: 0.8032
#
# Precision, Recall, F1:
# ai → Precision: 0.8899, Recall: 0.8992, F1: 0.8945
# human → Precision: 0.8182, Recall: 0.8032, F1: 0.8106
#
# False Positive Rate:
# ai: 0.1968
# human: 0.1008
#
# Overall Accuracy: 0.8645
# Average Inference Time per Sample: 0.041583 seconds
# ========================================
#
#
#
# === Trial 6/10: LR=0.001, WD=1e-06, Epochs=5 ===
# Epoch [1/5], train loss: 0.3716, train acc: 0.8262, val loss: 0.2955, val acc: 0.8597
# Epoch [2/5], train loss: 0.2553, train acc: 0.8875, val loss: 0.2918, val acc: 0.8723
# Epoch [3/5], train loss: 0.1785, train acc: 0.9260, val loss: 0.3626, val acc: 0.8546
# Epoch [4/5], train loss: 0.1089, train acc: 0.9572, val loss: 0.3807, val acc: 0.8621
# Epoch [5/5], train loss: 0.0730, train acc: 0.9727, val loss: 0.5005, val acc: 0.8567
# ===== Evaluation at 2025-05-05 12:53:49 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.001
# epochs: 5
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-06
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.8690
# human: 0.8349
#
# Precision, Recall, F1:
# ai → Precision: 0.9030, Recall: 0.8690, F1: 0.8857
# human → Precision: 0.7826, Recall: 0.8349, F1: 0.8079
#
# False Positive Rate:
# ai: 0.1651
# human: 0.1310
#
# Overall Accuracy: 0.8567
# Average Inference Time per Sample: 0.038497 seconds
# ========================================
#
#
#
# === Trial 7/10: LR=0.0001, WD=1e-06, Epochs=20 ===
# Epoch [1/20], train loss: 0.4975, train acc: 0.7502, val loss: 0.3874, val acc: 0.8290
# Epoch [2/20], train loss: 0.3522, train acc: 0.8401, val loss: 0.3462, val acc: 0.8353
# Epoch [3/20], train loss: 0.3156, train acc: 0.8579, val loss: 0.3315, val acc: 0.8431
# Epoch [4/20], train loss: 0.2837, train acc: 0.8739, val loss: 0.3251, val acc: 0.8516
# Epoch [5/20], train loss: 0.2564, train acc: 0.8885, val loss: 0.3252, val acc: 0.8534
# Epoch [6/20], train loss: 0.2254, train acc: 0.9023, val loss: 0.3304, val acc: 0.8509
# Epoch [7/20], train loss: 0.1875, train acc: 0.9229, val loss: 0.3379, val acc: 0.8543
# Epoch [8/20], train loss: 0.1575, train acc: 0.9384, val loss: 0.3543, val acc: 0.8579
# Epoch [9/20], train loss: 0.1225, train acc: 0.9583, val loss: 0.3750, val acc: 0.8555
# Epoch [10/20], train loss: 0.0942, train acc: 0.9715, val loss: 0.4052, val acc: 0.8558
# Epoch [11/20], train loss: 0.0700, train acc: 0.9813, val loss: 0.4344, val acc: 0.8546
# Epoch [12/20], train loss: 0.0568, train acc: 0.9865, val loss: 0.4247, val acc: 0.8458
# Epoch [13/20], train loss: 0.0439, train acc: 0.9905, val loss: 0.4664, val acc: 0.8458
# Epoch [14/20], train loss: 0.0285, train acc: 0.9968, val loss: 0.4871, val acc: 0.8497
# Epoch [15/20], train loss: 0.0245, train acc: 0.9963, val loss: 0.4990, val acc: 0.8534
# Epoch [16/20], train loss: 0.0192, train acc: 0.9972, val loss: 0.5357, val acc: 0.8506
# Epoch [17/20], train loss: 0.0185, train acc: 0.9970, val loss: 0.5390, val acc: 0.8452
# Epoch [18/20], train loss: 0.0176, train acc: 0.9965, val loss: 0.5651, val acc: 0.8446
# Epoch [19/20], train loss: 0.0133, train acc: 0.9984, val loss: 0.5716, val acc: 0.8470
# Epoch [20/20], train loss: 0.0127, train acc: 0.9980, val loss: 0.5926, val acc: 0.8434
# ===== Evaluation at 2025-05-05 16:55:38 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.0001
# epochs: 20
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.0001
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-06
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.8577
# human: 0.8182
#
# Precision, Recall, F1:
# ai → Precision: 0.8930, Recall: 0.8577, F1: 0.8750
# human → Precision: 0.7646, Recall: 0.8182, F1: 0.7905
#
# False Positive Rate:
# ai: 0.1818
# human: 0.1423
#
# Overall Accuracy: 0.8434
# Average Inference Time per Sample: 0.020078 seconds
# ========================================
#
#
#
# === Trial 8/10: LR=0.0005, WD=1e-07, Epochs=10 ===
# Epoch [1/10], train loss: 0.3964, train acc: 0.8098, val loss: 0.3062, val acc: 0.8558
# Epoch [2/10], train loss: 0.2668, train acc: 0.8804, val loss: 0.3033, val acc: 0.8543
# Epoch [3/10], train loss: 0.1936, train acc: 0.9175, val loss: 0.3291, val acc: 0.8567
# Epoch [4/10], train loss: 0.1172, train acc: 0.9554, val loss: 0.3812, val acc: 0.8600
# Epoch [5/10], train loss: 0.0541, train acc: 0.9808, val loss: 0.4321, val acc: 0.8627
# Epoch [6/10], train loss: 0.0299, train acc: 0.9912, val loss: 0.5000, val acc: 0.8618
# Epoch [7/10], train loss: 0.0273, train acc: 0.9907, val loss: 0.5539, val acc: 0.8389
# Epoch [8/10], train loss: 0.0249, train acc: 0.9923, val loss: 0.5195, val acc: 0.8558
# Epoch [9/10], train loss: 0.0226, train acc: 0.9924, val loss: 0.6024, val acc: 0.8654
# Epoch [10/10], train loss: 0.0187, train acc: 0.9945, val loss: 0.5796, val acc: 0.8525
# ===== Evaluation at 2025-05-05 18:02:55 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.0005
# epochs: 10
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.0005
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-07
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.8699
# human: 0.8215
#
# Precision, Recall, F1:
# ai → Precision: 0.8961, Recall: 0.8699, F1: 0.8828
# human → Precision: 0.7811, Recall: 0.8215, F1: 0.8008
#
# False Positive Rate:
# ai: 0.1785
# human: 0.1301
#
# Overall Accuracy: 0.8525
# Average Inference Time per Sample: 0.020187 seconds
# ========================================
#
#
#
# === Trial 9/10: LR=0.0001, WD=1e-08, Epochs=5 ===
# Epoch [1/5], train loss: 0.4893, train acc: 0.7577, val loss: 0.3803, val acc: 0.8257
# Epoch [2/5], train loss: 0.3564, train acc: 0.8384, val loss: 0.3367, val acc: 0.8455
# Epoch [3/5], train loss: 0.3137, train acc: 0.8595, val loss: 0.3221, val acc: 0.8537
# Epoch [4/5], train loss: 0.2815, train acc: 0.8763, val loss: 0.3176, val acc: 0.8525
# Epoch [5/5], train loss: 0.2504, train acc: 0.8943, val loss: 0.3171, val acc: 0.8549
# ===== Evaluation at 2025-05-05 18:37:08 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.0001
# epochs: 5
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.0001
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-08
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.8916
# human: 0.7898
#
# Precision, Recall, F1:
# ai → Precision: 0.8825, Recall: 0.8916, F1: 0.8870
# human → Precision: 0.8046, Recall: 0.7898, F1: 0.7971
#
# False Positive Rate:
# ai: 0.2102
# human: 0.1084
#
# Overall Accuracy: 0.8549
# Average Inference Time per Sample: 0.019399 seconds
# ========================================
#
#
#
# === Trial 10/10: LR=0.0001, WD=1e-07, Epochs=20 ===
# Epoch [1/20], train loss: 0.4818, train acc: 0.7611, val loss: 0.3660, val acc: 0.8332
# Epoch [2/20], train loss: 0.3445, train acc: 0.8443, val loss: 0.3313, val acc: 0.8446
# Epoch [3/20], train loss: 0.3076, train acc: 0.8615, val loss: 0.3173, val acc: 0.8561
# Epoch [4/20], train loss: 0.2816, train acc: 0.8744, val loss: 0.3148, val acc: 0.8567
# Epoch [5/20], train loss: 0.2507, train acc: 0.8897, val loss: 0.3124, val acc: 0.8609
# Epoch [6/20], train loss: 0.2222, train acc: 0.9053, val loss: 0.3166, val acc: 0.8612
# Epoch [7/20], train loss: 0.1904, train acc: 0.9220, val loss: 0.3295, val acc: 0.8561
# Epoch [8/20], train loss: 0.1531, train acc: 0.9399, val loss: 0.3442, val acc: 0.8588
# Epoch [9/20], train loss: 0.1255, train acc: 0.9554, val loss: 0.3603, val acc: 0.8609
# Epoch [10/20], train loss: 0.0956, train acc: 0.9704, val loss: 0.3847, val acc: 0.8600
# Epoch [11/20], train loss: 0.0725, train acc: 0.9801, val loss: 0.4142, val acc: 0.8600
# Epoch [12/20], train loss: 0.0546, train acc: 0.9865, val loss: 0.4345, val acc: 0.8443
# Epoch [13/20], train loss: 0.0417, train acc: 0.9905, val loss: 0.4621, val acc: 0.8516
# Epoch [14/20], train loss: 0.0311, train acc: 0.9952, val loss: 0.4773, val acc: 0.8506
# Epoch [15/20], train loss: 0.0253, train acc: 0.9956, val loss: 0.5107, val acc: 0.8573
# Epoch [16/20], train loss: 0.0185, train acc: 0.9977, val loss: 0.5282, val acc: 0.8500
# Epoch [17/20], train loss: 0.0191, train acc: 0.9968, val loss: 0.5428, val acc: 0.8573
# Epoch [18/20], train loss: 0.0155, train acc: 0.9974, val loss: 0.5587, val acc: 0.8564
# Epoch [19/20], train loss: 0.0142, train acc: 0.9977, val loss: 0.5638, val acc: 0.8509
# Epoch [20/20], train loss: 0.0105, train acc: 0.9990, val loss: 0.5956, val acc: 0.8522
# ===== Evaluation at 2025-05-05 20:17:32 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.0001
# epochs: 20
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.0001
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-07
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.9081
# human: 0.7531
#
# Precision, Recall, F1:
# ai → Precision: 0.8668, Recall: 0.9081, F1: 0.8870
# human → Precision: 0.8224, Recall: 0.7531, F1: 0.7862
#
# False Positive Rate:
# ai: 0.2469
# human: 0.0919
#
# Overall Accuracy: 0.8522
# Average Inference Time per Sample: 0.012344 seconds
# ========================================
#
#
#
# Best validation accuracy: 0.8798554652213189

# %%
model = get_model()
model.load_state_dict(torch.load("best_model.pt", map_location=device))
model.to(device)
model.eval()
results = []

for batch in tqdm(test_loader):
    inputs, labels, filenames = batch  # Unpack the filename from the dataset
    inputs = inputs.to(device)
    labels = labels.to(device)

    with torch.no_grad():
        outputs = model(inputs)
        probs = F.softmax(outputs, dim=1)

        for i in range(len(filenames)):
            results.append({
                "filename": filenames[i],  # Use filename directly from dataset
                "prob_ai": probs[i][0].item(),
                "prob_human": probs[i][1].item(),
                "true_label": labels[i].item(),
                "pred_label": torch.argmax(probs[i]).item()
            })

# Convert the results to a DataFrame
df = pd.DataFrame(results)

# Save to CSV
df.to_csv("best_cqt_test_large_predictions.csv", index=False)

# Preview results
print(df.head())
# Out:
#  20%|███████████▉                                               | 21/104 [00:41<02:42,  1.95s/it]
