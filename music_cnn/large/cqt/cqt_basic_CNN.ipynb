# %%
# https://medium.com/@imabhi1216/fine-tuning-a-pre-trained-resnet-18-model-for-image-classification-on-custom-dataset-with-pytorch-02df12e83c2c

# %%
import os
import shutil
from sklearn.model_selection import train_test_split
import random

import torch
import torchvision.models as models

from torchvision.datasets import ImageFolder
from torchvision.transforms import transforms
from torch.utils.data import Dataset, DataLoader

import time
from datetime import datetime
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix

import pandas as pd
import torch.nn.functional as F

from PIL import Image

from tqdm import tqdm

from itertools import product

# %%
def get_model():
    # Load the pre-trained ResNet-18 model
    model = models.resnet34(weights=models.ResNet34_Weights.DEFAULT)

    # Modify the last layer of the model
    num_classes = 2 # number of classes in dataset
    model.fc = torch.nn.Linear(model.fc.in_features, num_classes)
    return model

# %%
# Directory paths for the segments and lyrics
ai_segments_path = "/vol/bitbucket/sg2121/fypdataset/dataset_large2/normal_data/ai_segments"
human_segments_path = "/vol/bitbucket/sg2121/fypdataset/dataset_large2/normal_data/human"
ai_cqt_path = "/vol/bitbucket/sg2121/fypdataset/dataset_large2/features/ai/CQT"
human_cqt_path = "/vol/bitbucket/sg2121/fypdataset/dataset_large2/features/human/CQT"

# Helper function to read file paths from a text file
def read_file_paths(file_name):
    with open(file_name, 'r') as f:
        return [line.strip() for line in f.readlines()]

# Read all file paths from the text files
train_files = read_file_paths('/vol/bitbucket/sg2121/fyp/aimusicdetector/train_test_split/bitbucket/train_files_large.txt')
val_files = read_file_paths('/vol/bitbucket/sg2121/fyp/aimusicdetector/train_test_split/bitbucket/val_files_large.txt')
test_files = read_file_paths('/vol/bitbucket/sg2121/fyp/aimusicdetector/train_test_split/bitbucket/test_files_large.txt')


# Function to convert segment file path to lyric file path
def convert_to_cqt_path(file_path, is_ai):
    if is_ai:
        if file_path.startswith(ai_segments_path):
            base_cqt_path = ai_cqt_path
        else:
            return
    else:
        if file_path.startswith(human_segments_path):
            base_cqt_path = human_cqt_path
        else:
            return

    # Convert filename to cqt filename
    file_name = os.path.basename(file_path).replace('.mp3', '-CQT.png')
    return os.path.join(base_cqt_path, file_name)


# Process the file lists and create tuples of (lyric_path, label)
def process_file_paths(file_paths, is_ai):
    return [(convert_to_cqt_path(file_path, is_ai), 0 if is_ai else 1) for file_path in file_paths]

# Convert all file paths from the train, validation, and test sets
ai_train_files = process_file_paths(train_files, is_ai=True)
human_train_files = process_file_paths(train_files, is_ai=False)

ai_val_files = process_file_paths(val_files, is_ai=True)
human_val_files = process_file_paths(val_files, is_ai=False)

ai_test_files = process_file_paths(test_files, is_ai=True)
human_test_files = process_file_paths(test_files, is_ai=False)

def clean(paths):
    return [(p, l) for p, l in paths if p is not None]

train_files_combined = clean(ai_train_files) + clean(human_train_files)
val_files_combined = clean(ai_val_files) + clean(human_val_files)
test_files_combined = clean(ai_test_files) + clean(human_test_files)

# Shuffle the data if needed
random.shuffle(train_files_combined)
random.shuffle(val_files_combined)
random.shuffle(test_files_combined)

# Example of how you might check the splits
print(f"Training set size: {len(train_files_combined)}")
print(f"Validation set size: {len(val_files_combined)}")
print(f"Test set size: {len(test_files_combined)}")
# Out:
# Training set size: 22736
# Validation set size: 4871
# Test set size: 4875

# %%
# Custom dataset class
class CQTSpectrogramDataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        path, label = self.data[idx]
        image = Image.open(path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        filename = os.path.basename(path)
        return image, label, filename
        
transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
# Create datasets
train_dataset = CQTSpectrogramDataset(train_files_combined, transform=transform)
val_dataset = CQTSpectrogramDataset(val_files_combined, transform=transform)
test_dataset = CQTSpectrogramDataset(test_files_combined, transform=transform)

# DataLoaders
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Confirm sizes
print(f"Train set: {len(train_dataset)} samples")
print(f"Val set: {len(val_dataset)} samples")
print(f"Test set: {len(test_dataset)} samples")
# Out:
# Train set: 22736 samples
# Val set: 4871 samples
# Test set: 4875 samples

# %%
# Determine whether to use GPU (if available) or CPU
device = torch.device("mps" if torch.backends.mps.is_available() else "cuda" if torch.cuda.is_available() else "cpu")
print(device)

def train(model, train_loader, val_loader, criterion, optimizer, num_epochs):
    
    for epoch in range(num_epochs):
        # Set the model to training mode
        model.train()

        # Initialize running loss and correct predictions count for training
        running_loss = 0.0
        running_corrects = 0

        # Iterate over the training data loader
        for inputs, labels, filenames in train_loader:
            # Move inputs and labels to the device (GPU or CPU)
            inputs = inputs.to(device)
            labels = labels.to(device)

            # Reset the gradients to zero before the backward pass
            optimizer.zero_grad()

            # Forward pass: compute the model output
            outputs = model(inputs)
            # Get the predicted class (with the highest score)
            _, preds = torch.max(outputs, 1)
            # Compute the loss between the predictions and actual labels
            loss = criterion(outputs, labels)

            # Backward pass: compute gradients
            loss.backward()
            # Perform the optimization step to update model parameters
            optimizer.step()

            # Accumulate the running loss and the number of correct predictions
            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)

        # Compute average training loss and accuracy for this epoch
        train_loss = running_loss / len(train_loader.dataset)
        train_acc = running_corrects.float() / len(train_loader.dataset)

        # Set the model to evaluation mode for validation
        model.eval()
        # Initialize running loss and correct predictions count for validation
        running_loss = 0.0
        running_corrects = 0

        # Disable gradient computation for validation (saves memory and computations)
        with torch.no_grad():
            # Iterate over the validation data loader
            for inputs, labels, filenames in val_loader:
                # Move inputs and labels to the device (GPU or CPU)
                inputs = inputs.to(device)
                labels = labels.to(device)

                # Forward pass: compute the model output
                outputs = model(inputs)
                # Get the predicted class (with the highest score)
                _, preds = torch.max(outputs, 1)
                # Compute the loss between the predictions and actual labels
                loss = criterion(outputs, labels)

                # Accumulate the running loss and the number of correct predictions
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

        # Compute average validation loss and accuracy for this epoch
        val_loss = running_loss / len(val_loader.dataset)
        val_acc = running_corrects.float() / len(val_loader.dataset)

        # Print the results for the current epoch
        print(f'Epoch [{epoch+1}/{num_epochs}], train loss: {train_loss:.4f}, train acc: {train_acc:.4f}, val loss: {val_loss:.4f}, val acc: {val_acc:.4f}')
# Out:
# cuda

# %%
model = get_model()
model = model.to(device)

# Define the loss function and optimizer
lr = 0.001
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.fc.parameters(), lr, momentum=0.9)
num_epochs = 5

# %%
train(model, train_loader, val_loader, criterion, optimizer, num_epochs)
# Out:
# Epoch [1/5], train loss: 0.4065, train acc: 0.8283, val loss: 0.4348, val acc: 0.7988
# Epoch [2/5], train loss: 0.3887, train acc: 0.8377, val loss: 0.3734, val acc: 0.8423
# Epoch [3/5], train loss: 0.3809, train acc: 0.8412, val loss: 0.3677, val acc: 0.8446
# Epoch [4/5], train loss: 0.3759, train acc: 0.8444, val loss: 0.3692, val acc: 0.8454
# Epoch [5/5], train loss: 0.3748, train acc: 0.8423, val loss: 0.3777, val acc: 0.8456

# %%
def evaluate_model(model, test_loader, device, hyperparams=None):
    log_file = "/vol/bitbucket/sg2121/fyp/aimusicdetector/music_cnn/large/cqt/training_large_logfile.txt"

    model.eval()
    correct_pred = {classname: 0 for classname in ['ai', 'human']}
    total_pred = {classname: 0 for classname in ['ai', 'human']}

    all_labels = []
    all_preds = []
    
    start_time = time.time()

    with torch.no_grad():
        for inputs, labels, filenames in test_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            probs = F.softmax(outputs, dim=1)
            _, preds = torch.max(outputs, 1)

            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(preds.cpu().numpy())

            for label, prediction in zip(labels, preds):
                classname = 'ai' if label.item() == 0 else 'human'
                if label == prediction:
                    correct_pred[classname] += 1
                total_pred[classname] += 1

    end_time = time.time()
    avg_inference_time = (end_time - start_time) / len(test_loader.dataset)

    accuracy_per_class = {
        classname: correct_pred[classname] / total_pred[classname]
        if total_pred[classname] > 0 else 0
        for classname in ['ai', 'human']
    }

    overall_accuracy = accuracy_score(all_labels, all_preds)
    precision, recall, f1, _ = precision_recall_fscore_support(all_labels, all_preds, average=None, labels=[0, 1])
    cm = confusion_matrix(all_labels, all_preds)

    fpr = {}
    for i, classname in enumerate(['ai', 'human']):
        FP = cm[:, i].sum() - cm[i, i]
        TN = cm.sum() - (cm[i, :].sum() + cm[:, i].sum() - cm[i, i])
        fpr[classname] = FP / (FP + TN) if (FP + TN) > 0 else 0

    # Logging
    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    log_lines = [f"===== Evaluation at {timestamp} =====\n"]

    if hyperparams:
        log_lines.append("Hyperparameters:")
        for key, value in hyperparams.items():
            log_lines.append(f"{key}: {value}")
    else:
        log_lines.append("No hyperparameters provided.")
    log_lines.append("")

    log_lines.append("Accuracy per class:")
    for classname, acc in accuracy_per_class.items():
        log_lines.append(f"{classname}: {acc:.4f}")
    log_lines.append("\nPrecision, Recall, F1:")
    for i, classname in enumerate(['ai', 'human']):
        log_lines.append(f"{classname} → Precision: {precision[i]:.4f}, Recall: {recall[i]:.4f}, F1: {f1[i]:.4f}")
    log_lines.append("\nFalse Positive Rate:")
    for classname, rate in fpr.items():
        log_lines.append(f"{classname}: {rate:.4f}")
    log_lines.append(f"\nOverall Accuracy: {overall_accuracy:.4f}")
    log_lines.append(f"Average Inference Time per Sample: {avg_inference_time:.6f} seconds")
    log_lines.append("=" * 40 + "\n\n")

    print("\n".join(log_lines))
    with open(log_file, "a") as f:
        f.write("\n".join(log_lines))

    return overall_accuracy

# %%
model.eval()
results = []

for batch in tqdm(test_loader):
    inputs, labels, filenames = batch  # Unpack the filename from the dataset
    inputs = inputs.to(device)
    labels = labels.to(device)

    with torch.no_grad():
        outputs = model(inputs)
        probs = F.softmax(outputs, dim=1)

        for i in range(len(filenames)):
            results.append({
                "filename": filenames[i],  # Use filename directly from dataset
                "prob_ai": probs[i][0].item(),
                "prob_human": probs[i][1].item(),
                "true_label": labels[i].item(),
                "pred_label": torch.argmax(probs[i]).item()
            })

# Convert the results to a DataFrame
df = pd.DataFrame(results)

# Save to CSV
df.to_csv("cqt_test_large_predictions.csv", index=False)

# Preview results
print(df.head())
# Out:
# 100%|█████████████████████████████████| 153/153 [07:21<00:00,  2.88s/it]
#                     filename   prob_ai  prob_human  true_label  pred_label
# 0            H12942N-CQT.png  0.018060    0.981940           1           1
# 1             H4057N-CQT.png  0.020722    0.979278           1           1
# 2             H2140N-CQT.png  0.010398    0.989602           1           1
# 3            H22582N-CQT.png  0.186468    0.813532           1           1
# 4  U1286RN_segment_1-CQT.png  0.228539    0.771461           0           1

# %%
hyperparams = {
    "batch_size": batch_size,
    "learning_rate": lr,
    "epochs": num_epochs,
    "optimizer": optimizer,
    "model": model.__class__.__name__,
}

evaluate_model(model, test_loader, device, hyperparams=hyperparams)
# Out:
# ===== Evaluation at 2025-05-21 12:54:40 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.001
# epochs: 5
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 0
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.4396
# human: 0.9709
#
# Precision, Recall, F1:
# ai → Precision: 0.8195, Recall: 0.4396, F1: 0.5723
# human → Precision: 0.8523, Recall: 0.9709, F1: 0.9077
#
# False Positive Rate:
# ai: 0.0291
# human: 0.5604
#
# Overall Accuracy: 0.8482
# Average Inference Time per Sample: 0.095681 seconds
# ========================================
# 0.8482051282051282

# %%
# Define hyperparameter search space
learning_rates = [1e-3, 1e-4, 5e-4]
weight_decays = [1e-6, 1e-7, 1e-8]
epochs_list = [5, 10, 20] 

# Generate hyperparameter combinations and randomly select 10
param_combinations = list(product(learning_rates, weight_decays, epochs_list))
random.shuffle(param_combinations)
hyperparam_trials = param_combinations[:10]

# Run randomized search
best_model = None
best_acc = 0

for i, (lr, wd, epochs) in enumerate(hyperparam_trials):
    print(f"\n=== Trial {i+1}/10: LR={lr}, WD={wd}, Epochs={epochs} ===")

    model = get_model()
    model = model.to(device)
    
    # Use an optimizer like Adam or SGD (adjust based on your requirement)
    optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=0.9, weight_decay=wd)
    
    # Train the model (assuming you have a function to handle training)
    train(model, train_loader, val_loader, criterion, optimizer, epochs)

    hyperparams = {
        "batch_size": batch_size,
        "learning_rate": lr,
        "epochs": epochs,
        "optimizer": optimizer,
        "model": model.__class__.__name__,
    }
    
    val_acc = evaluate_model(model, val_loader, device, hyperparams=hyperparams)
    if val_acc > best_acc:
        best_acc = val_acc
        best_model = model
        torch.save(model.state_dict(), 'best_model.pt')
    
print("\nBest validation accuracy:", best_acc)
# Out:
# === Trial 1/10: LR=0.0001, WD=1e-07, Epochs=10 ===
# Epoch [1/10], train loss: 0.3750, train acc: 0.8400, val loss: 0.3086, val acc: 0.8643
# Epoch [2/10], train loss: 0.2832, train acc: 0.8795, val loss: 0.2847, val acc: 0.8754
# Epoch [3/10], train loss: 0.2513, train acc: 0.8938, val loss: 0.2693, val acc: 0.8826
# Epoch [4/10], train loss: 0.2230, train acc: 0.9086, val loss: 0.2586, val acc: 0.8889
# Epoch [5/10], train loss: 0.1971, train acc: 0.9201, val loss: 0.2649, val acc: 0.8920
# Epoch [6/10], train loss: 0.1728, train acc: 0.9311, val loss: 0.2583, val acc: 0.8912
# Epoch [7/10], train loss: 0.1458, train acc: 0.9440, val loss: 0.2646, val acc: 0.8916
# Epoch [8/10], train loss: 0.1175, train acc: 0.9579, val loss: 0.2782, val acc: 0.8873
# Epoch [9/10], train loss: 0.0975, train acc: 0.9665, val loss: 0.2919, val acc: 0.8811
# Epoch [10/10], train loss: 0.0715, train acc: 0.9784, val loss: 0.3097, val acc: 0.8861
# ===== Evaluation at 2025-05-22 05:31:00 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.0001
# epochs: 10
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.0001
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-07
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.6708
# human: 0.9506
#
# Precision, Recall, F1:
# ai → Precision: 0.8030, Recall: 0.6708, F1: 0.7310
# human → Precision: 0.9059, Recall: 0.9506, F1: 0.9277
#
# False Positive Rate:
# ai: 0.0494
# human: 0.3292
#
# Overall Accuracy: 0.8861
# Average Inference Time per Sample: 0.060906 seconds
# ========================================
#
#
#
# === Trial 2/10: LR=0.001, WD=1e-08, Epochs=5 ===
# Epoch [1/5], train loss: 0.2918, train acc: 0.8750, val loss: 0.2381, val acc: 0.8978
# Epoch [2/5], train loss: 0.2026, train acc: 0.9164, val loss: 0.2228, val acc: 0.9058
# Epoch [3/5], train loss: 0.1402, train acc: 0.9447, val loss: 0.2463, val acc: 0.9072
# Epoch [4/5], train loss: 0.0884, train acc: 0.9671, val loss: 0.2773, val acc: 0.8992
# Epoch [5/5], train loss: 0.0576, train acc: 0.9776, val loss: 0.3259, val acc: 0.8854
# ===== Evaluation at 2025-05-22 07:52:52 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.001
# epochs: 5
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-08
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.7402
# human: 0.9290
#
# Precision, Recall, F1:
# ai → Precision: 0.7577, Recall: 0.7402, F1: 0.7489
# human → Precision: 0.9226, Recall: 0.9290, F1: 0.9258
#
# False Positive Rate:
# ai: 0.0710
# human: 0.2598
#
# Overall Accuracy: 0.8854
# Average Inference Time per Sample: 0.060062 seconds
# ========================================
#
#
#
# === Trial 3/10: LR=0.001, WD=1e-06, Epochs=20 ===
# Epoch [1/20], train loss: 0.2971, train acc: 0.8723, val loss: 0.2358, val acc: 0.9062
# Epoch [2/20], train loss: 0.2052, train acc: 0.9156, val loss: 0.2337, val acc: 0.9070
# Epoch [3/20], train loss: 0.1421, train acc: 0.9448, val loss: 0.2465, val acc: 0.9082
# Epoch [4/20], train loss: 0.0884, train acc: 0.9654, val loss: 0.2976, val acc: 0.8986
# Epoch [5/20], train loss: 0.0614, train acc: 0.9765, val loss: 0.3689, val acc: 0.8789
# Epoch [6/20], train loss: 0.0427, train acc: 0.9837, val loss: 0.3489, val acc: 0.9052
# Epoch [7/20], train loss: 0.0277, train acc: 0.9900, val loss: 0.4032, val acc: 0.9029
# Epoch [8/20], train loss: 0.0300, train acc: 0.9893, val loss: 0.4462, val acc: 0.8807
# Epoch [9/20], train loss: 0.0234, train acc: 0.9920, val loss: 0.4073, val acc: 0.9062
# Epoch [10/20], train loss: 0.0166, train acc: 0.9947, val loss: 0.4637, val acc: 0.9049
# Epoch [11/20], train loss: 0.0160, train acc: 0.9944, val loss: 0.4201, val acc: 0.9086
# Epoch [12/20], train loss: 0.0086, train acc: 0.9974, val loss: 0.4548, val acc: 0.9101
# Epoch [13/20], train loss: 0.0097, train acc: 0.9967, val loss: 0.4673, val acc: 0.9045
# Epoch [14/20], train loss: 0.0077, train acc: 0.9976, val loss: 0.5386, val acc: 0.9052
# Epoch [15/20], train loss: 0.0070, train acc: 0.9974, val loss: 0.6151, val acc: 0.9019
# Epoch [16/20], train loss: 0.0099, train acc: 0.9963, val loss: 0.5980, val acc: 0.9000
# Epoch [17/20], train loss: 0.0108, train acc: 0.9959, val loss: 0.5102, val acc: 0.9006
# Epoch [18/20], train loss: 0.0089, train acc: 0.9975, val loss: 0.5034, val acc: 0.9080
# Epoch [19/20], train loss: 0.0077, train acc: 0.9975, val loss: 0.4416, val acc: 0.9068
# Epoch [20/20], train loss: 0.0080, train acc: 0.9969, val loss: 0.6012, val acc: 0.9029
# ===== Evaluation at 2025-05-22 17:49:22 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.001
# epochs: 20
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-06
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.6646
# human: 0.9744
#
# Precision, Recall, F1:
# ai → Precision: 0.8861, Recall: 0.6646, F1: 0.7595
# human → Precision: 0.9064, Recall: 0.9744, F1: 0.9392
#
# False Positive Rate:
# ai: 0.0256
# human: 0.3354
#
# Overall Accuracy: 0.9029
# Average Inference Time per Sample: 0.069692 seconds
# ========================================
#
#
#
# === Trial 4/10: LR=0.0005, WD=1e-07, Epochs=20 ===
# Epoch [1/20], train loss: 0.3222, train acc: 0.8645, val loss: 0.2510, val acc: 0.8963
# Epoch [2/20], train loss: 0.2222, train acc: 0.9064, val loss: 0.2411, val acc: 0.9008
# Epoch [3/20], train loss: 0.1639, train acc: 0.9349, val loss: 0.2484, val acc: 0.8984
# Epoch [4/20], train loss: 0.1025, train acc: 0.9615, val loss: 0.2980, val acc: 0.8932
# Epoch [5/20], train loss: 0.0556, train acc: 0.9804, val loss: 0.3203, val acc: 0.9010
# Epoch [6/20], train loss: 0.0341, train acc: 0.9894, val loss: 0.3833, val acc: 0.8943
# Epoch [7/20], train loss: 0.0226, train acc: 0.9929, val loss: 0.4193, val acc: 0.8867
# Epoch [8/20], train loss: 0.0221, train acc: 0.9927, val loss: 0.4229, val acc: 0.8887
# Epoch [9/20], train loss: 0.0171, train acc: 0.9940, val loss: 0.4161, val acc: 0.8986
# Epoch [10/20], train loss: 0.0134, train acc: 0.9960, val loss: 0.4822, val acc: 0.8920
# Epoch [11/20], train loss: 0.0155, train acc: 0.9946, val loss: 0.4485, val acc: 0.8969
# Epoch [12/20], train loss: 0.0115, train acc: 0.9962, val loss: 0.4827, val acc: 0.9039
# Epoch [13/20], train loss: 0.0111, train acc: 0.9963, val loss: 0.4728, val acc: 0.8951
# Epoch [14/20], train loss: 0.0141, train acc: 0.9956, val loss: 0.4436, val acc: 0.9006
# Epoch [15/20], train loss: 0.0078, train acc: 0.9976, val loss: 0.5052, val acc: 0.9027
# Epoch [16/20], train loss: 0.0061, train acc: 0.9982, val loss: 0.4988, val acc: 0.9043
# Epoch [17/20], train loss: 0.0055, train acc: 0.9986, val loss: 0.5292, val acc: 0.9041
# Epoch [18/20], train loss: 0.0057, train acc: 0.9984, val loss: 0.5140, val acc: 0.9068
# Epoch [19/20], train loss: 0.0039, train acc: 0.9989, val loss: 0.5430, val acc: 0.9052
# Epoch [20/20], train loss: 0.0028, train acc: 0.9993, val loss: 0.5207, val acc: 0.9103
# ===== Evaluation at 2025-05-23 02:51:39 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.0005
# epochs: 20
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.0005
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-07
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.7491
# human: 0.9586
#
# Precision, Recall, F1:
# ai → Precision: 0.8445, Recall: 0.7491, F1: 0.7940
# human → Precision: 0.9272, Recall: 0.9586, F1: 0.9427
#
# False Positive Rate:
# ai: 0.0414
# human: 0.2509
#
# Overall Accuracy: 0.9103
# Average Inference Time per Sample: 0.015573 seconds
# ========================================
#
#
#
# === Trial 5/10: LR=0.0001, WD=1e-08, Epochs=5 ===
# Epoch [1/5], train loss: 0.3916, train acc: 0.8310, val loss: 0.3075, val acc: 0.8688
# Epoch [2/5], train loss: 0.2858, train acc: 0.8790, val loss: 0.2780, val acc: 0.8813
# Epoch [3/5], train loss: 0.2515, train acc: 0.8943, val loss: 0.2686, val acc: 0.8883
# Epoch [4/5], train loss: 0.2244, train acc: 0.9070, val loss: 0.2589, val acc: 0.8904
# Epoch [5/5], train loss: 0.1942, train acc: 0.9229, val loss: 0.2602, val acc: 0.8918
# ===== Evaluation at 2025-05-23 03:30:09 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.0001
# epochs: 5
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.0001
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-08
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.7260
# human: 0.9416
#
# Precision, Recall, F1:
# ai → Precision: 0.7884, Recall: 0.7260, F1: 0.7559
# human → Precision: 0.9197, Recall: 0.9416, F1: 0.9305
#
# False Positive Rate:
# ai: 0.0584
# human: 0.2740
#
# Overall Accuracy: 0.8918
# Average Inference Time per Sample: 0.015746 seconds
# ========================================
#
#
#
# === Trial 6/10: LR=0.001, WD=1e-08, Epochs=20 ===
# Epoch [1/20], train loss: 0.3001, train acc: 0.8723, val loss: 0.2606, val acc: 0.8916
# Epoch [2/20], train loss: 0.2041, train acc: 0.9152, val loss: 0.2358, val acc: 0.8996
# Epoch [3/20], train loss: 0.1444, train acc: 0.9413, val loss: 0.2548, val acc: 0.9008
# Epoch [4/20], train loss: 0.0896, train acc: 0.9659, val loss: 0.2896, val acc: 0.9006
# Epoch [5/20], train loss: 0.0552, train acc: 0.9801, val loss: 0.3472, val acc: 0.8943
# Epoch [6/20], train loss: 0.0427, train acc: 0.9846, val loss: 0.3565, val acc: 0.9023
# Epoch [7/20], train loss: 0.0315, train acc: 0.9884, val loss: 0.3887, val acc: 0.9033
# Epoch [8/20], train loss: 0.0252, train acc: 0.9914, val loss: 0.5057, val acc: 0.9029
# Epoch [9/20], train loss: 0.0235, train acc: 0.9910, val loss: 0.4501, val acc: 0.8920
# Epoch [10/20], train loss: 0.0192, train acc: 0.9931, val loss: 0.4268, val acc: 0.9052
# Epoch [11/20], train loss: 0.0173, train acc: 0.9932, val loss: 0.4725, val acc: 0.9019
# Epoch [12/20], train loss: 0.0126, train acc: 0.9959, val loss: 0.4458, val acc: 0.9082
# Epoch [13/20], train loss: 0.0088, train acc: 0.9969, val loss: 0.4628, val acc: 0.9004
# Epoch [14/20], train loss: 0.0166, train acc: 0.9943, val loss: 0.4932, val acc: 0.9027
# Epoch [15/20], train loss: 0.0083, train acc: 0.9971, val loss: 0.5812, val acc: 0.9027
# Epoch [16/20], train loss: 0.0077, train acc: 0.9972, val loss: 0.5138, val acc: 0.9070
# Epoch [17/20], train loss: 0.0081, train acc: 0.9972, val loss: 0.5039, val acc: 0.9062
# Epoch [18/20], train loss: 0.0075, train acc: 0.9973, val loss: 0.4894, val acc: 0.9070
# Epoch [19/20], train loss: 0.0107, train acc: 0.9966, val loss: 0.4839, val acc: 0.9039
# Epoch [20/20], train loss: 0.0051, train acc: 0.9985, val loss: 0.4976, val acc: 0.9091
# ===== Evaluation at 2025-05-23 05:59:34 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.001
# epochs: 20
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-08
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.7393
# human: 0.9600
#
# Precision, Recall, F1:
# ai → Precision: 0.8471, Recall: 0.7393, F1: 0.7895
# human → Precision: 0.9247, Recall: 0.9600, F1: 0.9420
#
# False Positive Rate:
# ai: 0.0400
# human: 0.2607
#
# Overall Accuracy: 0.9091
# Average Inference Time per Sample: 0.015699 seconds
# ========================================
#
#
#
# === Trial 7/10: LR=0.0005, WD=1e-06, Epochs=20 ===
# Epoch [1/20], train loss: 0.3095, train acc: 0.8658, val loss: 0.2436, val acc: 0.8992
# Epoch [2/20], train loss: 0.2159, train acc: 0.9098, val loss: 0.2379, val acc: 0.8945
# Epoch [3/20], train loss: 0.1559, train acc: 0.9365, val loss: 0.2487, val acc: 0.9039
# Epoch [4/20], train loss: 0.0966, train acc: 0.9643, val loss: 0.2949, val acc: 0.8910
# Epoch [5/20], train loss: 0.0465, train acc: 0.9837, val loss: 0.3579, val acc: 0.8998
# Epoch [6/20], train loss: 0.0381, train acc: 0.9873, val loss: 0.3781, val acc: 0.8957
# Epoch [7/20], train loss: 0.0328, train acc: 0.9887, val loss: 0.3755, val acc: 0.8974
# Epoch [8/20], train loss: 0.0217, train acc: 0.9928, val loss: 0.3990, val acc: 0.8941
# Epoch [9/20], train loss: 0.0189, train acc: 0.9935, val loss: 0.4315, val acc: 0.8943
# Epoch [10/20], train loss: 0.0147, train acc: 0.9949, val loss: 0.4348, val acc: 0.9015
# Epoch [11/20], train loss: 0.0113, train acc: 0.9963, val loss: 0.4639, val acc: 0.8988
# Epoch [12/20], train loss: 0.0110, train acc: 0.9966, val loss: 0.4533, val acc: 0.9056
# Epoch [13/20], train loss: 0.0067, train acc: 0.9979, val loss: 0.4943, val acc: 0.9000
# Epoch [14/20], train loss: 0.0048, train acc: 0.9986, val loss: 0.5440, val acc: 0.8984
# Epoch [15/20], train loss: 0.0046, train acc: 0.9988, val loss: 0.4991, val acc: 0.8957
# Epoch [16/20], train loss: 0.0078, train acc: 0.9972, val loss: 0.5625, val acc: 0.8982
# Epoch [17/20], train loss: 0.0073, train acc: 0.9975, val loss: 0.5137, val acc: 0.8965
# Epoch [18/20], train loss: 0.0069, train acc: 0.9977, val loss: 0.5132, val acc: 0.8904
# Epoch [19/20], train loss: 0.0055, train acc: 0.9982, val loss: 0.5098, val acc: 0.8935
# Epoch [20/20], train loss: 0.0039, train acc: 0.9988, val loss: 0.5263, val acc: 0.8980
# ===== Evaluation at 2025-05-23 08:28:56 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.0005
# epochs: 20
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.0005
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-06
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.7322
# human: 0.9477
#
# Precision, Recall, F1:
# ai → Precision: 0.8077, Recall: 0.7322, F1: 0.7681
# human → Precision: 0.9219, Recall: 0.9477, F1: 0.9346
#
# False Positive Rate:
# ai: 0.0523
# human: 0.2678
#
# Overall Accuracy: 0.8980
# Average Inference Time per Sample: 0.016072 seconds
# ========================================
#
#
#
# === Trial 8/10: LR=0.0005, WD=1e-07, Epochs=10 ===
# Epoch [1/10], train loss: 0.3140, train acc: 0.8662, val loss: 0.2519, val acc: 0.8937
# Epoch [2/10], train loss: 0.2147, train acc: 0.9109, val loss: 0.2382, val acc: 0.9000
# Epoch [3/10], train loss: 0.1564, train acc: 0.9380, val loss: 0.2515, val acc: 0.9004
# Epoch [4/10], train loss: 0.0929, train acc: 0.9656, val loss: 0.3263, val acc: 0.8916
# Epoch [5/10], train loss: 0.0503, train acc: 0.9837, val loss: 0.3536, val acc: 0.8957
# Epoch [6/10], train loss: 0.0346, train acc: 0.9880, val loss: 0.3983, val acc: 0.8893
# Epoch [7/10], train loss: 0.0271, train acc: 0.9905, val loss: 0.4226, val acc: 0.8916
# Epoch [8/10], train loss: 0.0226, train acc: 0.9920, val loss: 0.4120, val acc: 0.8957
# Epoch [9/10], train loss: 0.0195, train acc: 0.9935, val loss: 0.4636, val acc: 0.9000
# Epoch [10/10], train loss: 0.0158, train acc: 0.9945, val loss: 0.4761, val acc: 0.8984
# ===== Evaluation at 2025-05-23 09:44:21 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.0005
# epochs: 10
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.0005
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-07
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.7375
# human: 0.9466
#
# Precision, Recall, F1:
# ai → Precision: 0.8056, Recall: 0.7375, F1: 0.7701
# human → Precision: 0.9232, Recall: 0.9466, F1: 0.9348
#
# False Positive Rate:
# ai: 0.0534
# human: 0.2625
#
# Overall Accuracy: 0.8984
# Average Inference Time per Sample: 0.015463 seconds
# ========================================
#
#
#
# === Trial 9/10: LR=0.0001, WD=1e-08, Epochs=20 ===
# Epoch [1/20], train loss: 0.3747, train acc: 0.8383, val loss: 0.3077, val acc: 0.8657
# Epoch [2/20], train loss: 0.2826, train acc: 0.8778, val loss: 0.2798, val acc: 0.8795
# Epoch [3/20], train loss: 0.2491, train acc: 0.8969, val loss: 0.2724, val acc: 0.8850
# Epoch [4/20], train loss: 0.2235, train acc: 0.9092, val loss: 0.2655, val acc: 0.8856
# Epoch [5/20], train loss: 0.1964, train acc: 0.9204, val loss: 0.2595, val acc: 0.8908
# Epoch [6/20], train loss: 0.1760, train acc: 0.9312, val loss: 0.2654, val acc: 0.8959
# Epoch [7/20], train loss: 0.1495, train acc: 0.9421, val loss: 0.2631, val acc: 0.8949
# Epoch [8/20], train loss: 0.1210, train acc: 0.9566, val loss: 0.2694, val acc: 0.8941
# Epoch [9/20], train loss: 0.0976, train acc: 0.9668, val loss: 0.2881, val acc: 0.8889
# Epoch [10/20], train loss: 0.0752, train acc: 0.9759, val loss: 0.3078, val acc: 0.8941
# Epoch [11/20], train loss: 0.0584, train acc: 0.9825, val loss: 0.3219, val acc: 0.8906
# Epoch [12/20], train loss: 0.0401, train acc: 0.9897, val loss: 0.3466, val acc: 0.8906
# Epoch [13/20], train loss: 0.0332, train acc: 0.9920, val loss: 0.3714, val acc: 0.8914
# Epoch [14/20], train loss: 0.0240, train acc: 0.9946, val loss: 0.3840, val acc: 0.8896
# Epoch [15/20], train loss: 0.0209, train acc: 0.9955, val loss: 0.3941, val acc: 0.8912
# Epoch [16/20], train loss: 0.0150, train acc: 0.9975, val loss: 0.4253, val acc: 0.8916
# Epoch [17/20], train loss: 0.0128, train acc: 0.9980, val loss: 0.4167, val acc: 0.8893
# Epoch [18/20], train loss: 0.0111, train acc: 0.9980, val loss: 0.4266, val acc: 0.8889
# Epoch [19/20], train loss: 0.0101, train acc: 0.9983, val loss: 0.4399, val acc: 0.8883
# Epoch [20/20], train loss: 0.0086, train acc: 0.9985, val loss: 0.4540, val acc: 0.8891
# ===== Evaluation at 2025-05-23 11:39:48 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.0001
# epochs: 20
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.0001
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-08
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.7224
# human: 0.9392
#
# Precision, Recall, F1:
# ai → Precision: 0.7808, Recall: 0.7224, F1: 0.7505
# human → Precision: 0.9186, Recall: 0.9392, F1: 0.9287
#
# False Positive Rate:
# ai: 0.0608
# human: 0.2776
#
# Overall Accuracy: 0.8891
# Average Inference Time per Sample: 0.011538 seconds
# ========================================
#
#
#
# === Trial 10/10: LR=0.0001, WD=1e-08, Epochs=10 ===
# Epoch [1/10], train loss: 0.3892, train acc: 0.8308, val loss: 0.3201, val acc: 0.8620
# Epoch [2/10], train loss: 0.2877, train acc: 0.8801, val loss: 0.2793, val acc: 0.8742
# Epoch [3/10], train loss: 0.2539, train acc: 0.8933, val loss: 0.2707, val acc: 0.8846
# Epoch [4/10], train loss: 0.2261, train acc: 0.9062, val loss: 0.2588, val acc: 0.8844
# Epoch [5/10], train loss: 0.1993, train acc: 0.9190, val loss: 0.2622, val acc: 0.8900
# Epoch [6/10], train loss: 0.1779, train acc: 0.9286, val loss: 0.2630, val acc: 0.8887
# Epoch [7/10], train loss: 0.1480, train acc: 0.9426, val loss: 0.2698, val acc: 0.8902
# Epoch [8/10], train loss: 0.1242, train acc: 0.9545, val loss: 0.2809, val acc: 0.8805
# Epoch [9/10], train loss: 0.0978, train acc: 0.9651, val loss: 0.2947, val acc: 0.8910
# Epoch [10/10], train loss: 0.0733, train acc: 0.9768, val loss: 0.3149, val acc: 0.8801
# ===== Evaluation at 2025-05-23 12:35:52 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.0001
# epochs: 10
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.0001
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-08
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.7456
# human: 0.9205
#
# Precision, Recall, F1:
# ai → Precision: 0.7377, Recall: 0.7456, F1: 0.7416
# human → Precision: 0.9234, Recall: 0.9205, F1: 0.9219
#
# False Positive Rate:
# ai: 0.0795
# human: 0.2544
#
# Overall Accuracy: 0.8801
# Average Inference Time per Sample: 0.011803 seconds
# ========================================
#
#
#
# Best validation accuracy: 0.9102853623485937

# %%
model = get_model()
model.load_state_dict(torch.load("best_model.pt", map_location=device))
model.to(device)
model.eval()
results = []

for batch in tqdm(test_loader):
    inputs, labels, filenames = batch  # Unpack the filename from the dataset
    inputs = inputs.to(device)
    labels = labels.to(device)

    with torch.no_grad():
        outputs = model(inputs)
        probs = F.softmax(outputs, dim=1)

        for i in range(len(filenames)):
            results.append({
                "filename": filenames[i],  # Use filename directly from dataset
                "prob_ai": probs[i][0].item(),
                "prob_human": probs[i][1].item(),
                "true_label": labels[i].item(),
                "pred_label": torch.argmax(probs[i]).item()
            })

# Convert the results to a DataFrame
df = pd.DataFrame(results)

# Save to CSV
df.to_csv("best_cqt_test_large_predictions.csv", index=False)

# Preview results
print(df.head())
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 153/153 [02:47<00:00,  1.10s/it]
#                     filename   prob_ai  prob_human  true_label  pred_label
# 0              H710N-CQT.png  0.999522    0.000478           1           0
# 1  S3418RN_segment_2-CQT.png  0.999982    0.000018           0           0
# 2            H10754N-CQT.png  0.710293    0.289707           1           0
# 3             H4209N-CQT.png  0.000001    0.999999           1           1
# 4            H13220N-CQT.png  0.000005    0.999995           1           1
