# %%
# https://medium.com/@imabhi1216/fine-tuning-a-pre-trained-resnet-18-model-for-image-classification-on-custom-dataset-with-pytorch-02df12e83c2c

# %%
print("HELLO")
# Out:
# HELLO

# %%
import os
import shutil
from sklearn.model_selection import train_test_split
import random

import torch
import torchvision.models as models

from torchvision.datasets import ImageFolder
from torchvision.transforms import transforms
from torch.utils.data import Dataset, DataLoader

import time
from datetime import datetime
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix

import pandas as pd
import torch.nn.functional as F

from PIL import Image

from tqdm import tqdm

from itertools import product

# %%
def get_model():
    # Load the pre-trained ResNet-18 model
    model = models.resnet34(weights=models.ResNet34_Weights.DEFAULT)

    # Modify the last layer of the model
    num_classes = 2 # number of classes in dataset
    model.fc = torch.nn.Linear(model.fc.in_features, num_classes)
    return model

# %%
# Directory paths for the segments and lyrics
ai_segments_path = "/vol/bitbucket/sg2121/fypdataset/dataset_large2/normal_data/ai_segments"
human_segments_path = "/vol/bitbucket/sg2121/fypdataset/dataset_large2/normal_data/human"
ai_mel_path = "/vol/bitbucket/sg2121/fypdataset/dataset_large2/features/ai/Mel_Spectrogram"
human_mel_path = "/vol/bitbucket/sg2121/fypdataset/dataset_large2/features/human/Mel_Spectrogram"

ai_aug_segments_path = "/vol/bitbucket/sg2121/fypdataset/dataset_large2/normal_data/augmented_ai"
ai_aug_mel_path = "/vol/bitbucket/sg2121/fypdataset/dataset_large2/features/ai_aug/Mel_Spectrogram"

# Helper function to read file paths from a text file
def read_file_paths(file_name):
    with open(file_name, 'r') as f:
        return [line.strip() for line in f.readlines()]

# Read all file paths from the text files
train_files = read_file_paths('/vol/bitbucket/sg2121/fyp/aimusicdetector/train_test_split/bitbucket/augmented/train_files_w_aug.txt')
val_files = read_file_paths('/vol/bitbucket/sg2121/fyp/aimusicdetector/train_test_split/bitbucket/augmented/val_files_w_aug.txt')
test_files = read_file_paths('/vol/bitbucket/sg2121/fyp/aimusicdetector/train_test_split/bitbucket/augmented/test_files_w_aug.txt')

# Function to convert segment file path to lyric file path
def convert_to_mel_path(file_path, is_ai):
    if is_ai:
        if file_path.startswith(ai_aug_segments_path):
            base_mel_path = ai_aug_mel_path
        elif file_path.startswith(ai_segments_path):
            base_mel_path = ai_mel_path
        else:
            return
    else:
        if file_path.startswith(human_segments_path):
            base_mel_path = human_mel_path
        else:
            return

    # Convert filename to mel filename
    file_name = os.path.basename(file_path).replace('.mp3', '-Mel_Spectrogram.png')
    return os.path.join(base_mel_path, file_name)

# Process the file lists and create tuples of (lyric_path, label)
def process_file_paths(file_paths, is_ai):
    return [(convert_to_mel_path(file_path, is_ai), 0 if is_ai else 1) for file_path in file_paths]

# Convert all file paths from the train, validation, and test sets
ai_train_files = process_file_paths(train_files, is_ai=True)
human_train_files = process_file_paths(train_files, is_ai=False)

ai_val_files = process_file_paths(val_files, is_ai=True)
human_val_files = process_file_paths(val_files, is_ai=False)

ai_test_files = process_file_paths(test_files, is_ai=True)
human_test_files = process_file_paths(test_files, is_ai=False)

def clean(paths):
    return [(p, l) for p, l in paths if p is not None]

train_files_combined = clean(ai_train_files) + clean(human_train_files)
val_files_combined = clean(ai_val_files) + clean(human_val_files)
test_files_combined = clean(ai_test_files) + clean(human_test_files)

# Shuffle the data if needed
random.shuffle(train_files_combined)
random.shuffle(val_files_combined)
random.shuffle(test_files_combined)

# Example of how you might check the splits
print(f"Training set size: {len(train_files_combined)}")
print(f"Validation set size: {len(val_files_combined)}")
print(f"Test set size: {len(test_files_combined)}")
# Out:
# Training set size: 37297
# Validation set size: 7991
# Test set size: 7995

# %%
# Custom dataset class
class MelSpectrogramDataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        path, label = self.data[idx]
        image = Image.open(path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        filename = os.path.basename(path)
        return image, label, filename
        
transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
# Create datasets
train_dataset = MelSpectrogramDataset(train_files_combined, transform=transform)
val_dataset = MelSpectrogramDataset(val_files_combined, transform=transform)
test_dataset = MelSpectrogramDataset(test_files_combined, transform=transform)

# DataLoaders
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Confirm sizes
print(f"Train set: {len(train_dataset)} samples")
print(f"Val set: {len(val_dataset)} samples")
print(f"Test set: {len(test_dataset)} samples")
# Out:
# Train set: 37297 samples
# Val set: 7991 samples
# Test set: 7995 samples

# %%
# Determine whether to use GPU (if available) or CPU
device = torch.device("mps" if torch.backends.mps.is_available() else "cuda" if torch.cuda.is_available() else "cpu")
print(device)

def train(model, train_loader, val_loader, criterion, optimizer, num_epochs):
    
    for epoch in range(num_epochs):
        # Set the model to training mode
        model.train()

        # Initialize running loss and correct predictions count for training
        running_loss = 0.0
        running_corrects = 0

        # Iterate over the training data loader
        for inputs, labels, filenames in train_loader:
            # Move inputs and labels to the device (GPU or CPU)
            inputs = inputs.to(device)
            labels = labels.to(device)

            # Reset the gradients to zero before the backward pass
            optimizer.zero_grad()

            # Forward pass: compute the model output
            outputs = model(inputs)
            # Get the predicted class (with the highest score)
            _, preds = torch.max(outputs, 1)
            # Compute the loss between the predictions and actual labels
            loss = criterion(outputs, labels)

            # Backward pass: compute gradients
            loss.backward()
            # Perform the optimization step to update model parameters
            optimizer.step()

            # Accumulate the running loss and the number of correct predictions
            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)

        # Compute average training loss and accuracy for this epoch
        train_loss = running_loss / len(train_loader.dataset)
        train_acc = running_corrects.float() / len(train_loader.dataset)

        # Set the model to evaluation mode for validation
        model.eval()
        # Initialize running loss and correct predictions count for validation
        running_loss = 0.0
        running_corrects = 0

        # Disable gradient computation for validation (saves memory and computations)
        with torch.no_grad():
            # Iterate over the validation data loader
            for inputs, labels, filenames in val_loader:
                # Move inputs and labels to the device (GPU or CPU)
                inputs = inputs.to(device)
                labels = labels.to(device)

                # Forward pass: compute the model output
                outputs = model(inputs)
                # Get the predicted class (with the highest score)
                _, preds = torch.max(outputs, 1)
                # Compute the loss between the predictions and actual labels
                loss = criterion(outputs, labels)

                # Accumulate the running loss and the number of correct predictions
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

        # Compute average validation loss and accuracy for this epoch
        val_loss = running_loss / len(val_loader.dataset)
        val_acc = running_corrects.float() / len(val_loader.dataset)

        # Print the results for the current epoch
        print(f'Epoch [{epoch+1}/{num_epochs}], train loss: {train_loss:.4f}, train acc: {train_acc:.4f}, val loss: {val_loss:.4f}, val acc: {val_acc:.4f}')
# Out:
# cuda

# %%
model = get_model()
model = model.to(device)

# Define the loss function and optimizer
lr = 0.001
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.fc.parameters(), lr, momentum=0.9)
num_epochs = 5

# %%
# best hyperparameters from search
lr = 0.001
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=0.9, weight_decay=1e-08)
num_epochs = 20

# %%
train(model, train_loader, val_loader, criterion, optimizer, num_epochs)
# Out:
# Epoch [1/20], train loss: 0.1576, train acc: 0.9346, val loss: 0.0928, val acc: 0.9602
# Epoch [2/20], train loss: 0.0792, train acc: 0.9691, val loss: 0.0791, val acc: 0.9670
# Epoch [3/20], train loss: 0.0456, train acc: 0.9830, val loss: 0.0836, val acc: 0.9690
# Epoch [4/20], train loss: 0.0281, train acc: 0.9897, val loss: 0.0747, val acc: 0.9737
# Epoch [5/20], train loss: 0.0176, train acc: 0.9937, val loss: 0.0808, val acc: 0.9707
# Epoch [6/20], train loss: 0.0114, train acc: 0.9964, val loss: 0.0844, val acc: 0.9725
# Epoch [7/20], train loss: 0.0083, train acc: 0.9972, val loss: 0.1144, val acc: 0.9692
# Epoch [8/20], train loss: 0.0073, train acc: 0.9977, val loss: 0.1128, val acc: 0.9696
# Epoch [9/20], train loss: 0.0047, train acc: 0.9986, val loss: 0.1037, val acc: 0.9705
# Epoch [10/20], train loss: 0.0049, train acc: 0.9985, val loss: 0.1156, val acc: 0.9667
# Epoch [11/20], train loss: 0.0040, train acc: 0.9987, val loss: 0.0960, val acc: 0.9752
# Epoch [12/20], train loss: 0.0025, train acc: 0.9993, val loss: 0.1040, val acc: 0.9743
# Epoch [13/20], train loss: 0.0013, train acc: 0.9998, val loss: 0.0983, val acc: 0.9745
# Epoch [14/20], train loss: 0.0015, train acc: 0.9995, val loss: 0.1075, val acc: 0.9727
# Epoch [15/20], train loss: 0.0016, train acc: 0.9996, val loss: 0.1044, val acc: 0.9731
# Epoch [16/20], train loss: 0.0021, train acc: 0.9994, val loss: 0.1086, val acc: 0.9716
# Epoch [17/20], train loss: 0.0018, train acc: 0.9994, val loss: 0.1101, val acc: 0.9745
# Epoch [18/20], train loss: 0.0006, train acc: 1.0000, val loss: 0.1097, val acc: 0.9757
# Epoch [19/20], train loss: 0.0023, train acc: 0.9993, val loss: 0.1314, val acc: 0.9698
# Epoch [20/20], train loss: 0.0046, train acc: 0.9986, val loss: 0.1006, val acc: 0.9750

# %%
def evaluate_model(model, test_loader, device, hyperparams=None):
    log_file = "/vol/bitbucket/sg2121/fyp/aimusicdetector/music_cnn/large/mel-spec/training_large_logfile.txt"

    model.eval()
    correct_pred = {classname: 0 for classname in ['ai', 'human']}
    total_pred = {classname: 0 for classname in ['ai', 'human']}

    all_labels = []
    all_preds = []
    
    start_time = time.time()

    with torch.no_grad():
        for inputs, labels, filenames in test_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            probs = F.softmax(outputs, dim=1)
            _, preds = torch.max(outputs, 1)

            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(preds.cpu().numpy())

            for label, prediction in zip(labels, preds):
                classname = 'ai' if label.item() == 0 else 'human'
                if label == prediction:
                    correct_pred[classname] += 1
                total_pred[classname] += 1

    end_time = time.time()
    avg_inference_time = (end_time - start_time) / len(test_loader.dataset)

    accuracy_per_class = {
        classname: correct_pred[classname] / total_pred[classname]
        if total_pred[classname] > 0 else 0
        for classname in ['ai', 'human']
    }

    overall_accuracy = accuracy_score(all_labels, all_preds)
    precision, recall, f1, _ = precision_recall_fscore_support(all_labels, all_preds, average=None, labels=[0, 1])
    cm = confusion_matrix(all_labels, all_preds)

    fpr = {}
    for i, classname in enumerate(['ai', 'human']):
        FP = cm[:, i].sum() - cm[i, i]
        TN = cm.sum() - (cm[i, :].sum() + cm[:, i].sum() - cm[i, i])
        fpr[classname] = FP / (FP + TN) if (FP + TN) > 0 else 0

    # Logging
    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    log_lines = [f"===== Evaluation at {timestamp} =====\n"]

    if hyperparams:
        log_lines.append("Hyperparameters:")
        for key, value in hyperparams.items():
            log_lines.append(f"{key}: {value}")
    else:
        log_lines.append("No hyperparameters provided.")
    log_lines.append("")

    log_lines.append("Accuracy per class:")
    for classname, acc in accuracy_per_class.items():
        log_lines.append(f"{classname}: {acc:.4f}")
    log_lines.append("\nPrecision, Recall, F1:")
    for i, classname in enumerate(['ai', 'human']):
        log_lines.append(f"{classname} → Precision: {precision[i]:.4f}, Recall: {recall[i]:.4f}, F1: {f1[i]:.4f}")
    log_lines.append("\nFalse Positive Rate:")
    for classname, rate in fpr.items():
        log_lines.append(f"{classname}: {rate:.4f}")
    log_lines.append(f"\nOverall Accuracy: {overall_accuracy:.4f}")
    log_lines.append(f"Average Inference Time per Sample: {avg_inference_time:.6f} seconds")
    log_lines.append("=" * 40 + "\n\n")

    print("\n".join(log_lines))
    with open(log_file, "a") as f:
        f.write("\n".join(log_lines))

    return overall_accuracy

# %%
model.eval()
results = []

for batch in tqdm(test_loader):
    inputs, labels, filenames = batch  # Unpack the filename from the dataset
    inputs = inputs.to(device)
    labels = labels.to(device)

    with torch.no_grad():
        outputs = model(inputs)
        probs = F.softmax(outputs, dim=1)

        for i in range(len(filenames)):
            results.append({
                "filename": filenames[i],  # Use filename directly from dataset
                "prob_ai": probs[i][0].item(),
                "prob_human": probs[i][1].item(),
                "true_label": labels[i].item(),
                "pred_label": torch.argmax(probs[i]).item()
            })

# Convert the results to a DataFrame
df = pd.DataFrame(results)

# Save to CSV
df.to_csv("mel-spec_test_large_with_aug_predictions.csv", index=False)

# Preview results
print(df.head())
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 250/250 [04:28<00:00,  1.07s/it]
#                                           filename       prob_ai  \
# 0                        H279N-Mel_Spectrogram.png  1.109998e-09
# 1                       H8167N-Mel_Spectrogram.png  6.551629e-10
# 2            S4594RN_segment_1-Mel_Spectrogram.png  1.000000e+00
# 3   U524RN_segment_1_stretched-Mel_Spectrogram.png  1.000000e+00
# 4  U1301RN_segment_2_stretched-Mel_Spectrogram.png  9.999869e-01
#
#      prob_human  true_label  pred_label
# 0  1.000000e+00           1           1
# 1  1.000000e+00           1           1
# 2  8.372044e-13           0           0
# 3  5.991907e-10           0           0
# 4  1.315380e-05           0           0

# %%
torch.save(model.state_dict(), 'cur_model.pt')

# %%
hyperparams = {
    "batch_size": batch_size,
    "learning_rate": lr,
    "epochs": num_epochs,
    "optimizer": optimizer,
    "model": model.__class__.__name__,
}

evaluate_model(model, test_loader, device, hyperparams=hyperparams)
# Out:
# ===== Evaluation at 2025-05-28 01:47:53 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.001
# epochs: 20
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-08
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.9717
# human: 0.9757
#
# Precision, Recall, F1:
# ai → Precision: 0.9784, Recall: 0.9717, F1: 0.9751
# human → Precision: 0.9682, Recall: 0.9757, F1: 0.9720
#
# False Positive Rate:
# ai: 0.0243
# human: 0.0283
#
# Overall Accuracy: 0.9736
# Average Inference Time per Sample: 0.010622 seconds
# ========================================
# 0.9736085053158224

# %% [markdown]
# HYPERPARAM SEARCH BELOW

# %%
# Define hyperparameter search space
learning_rates = [1e-3, 1e-4, 5e-4]
weight_decays = [1e-6, 1e-7, 1e-8]
epochs_list = [5, 10, 20] 

# Generate hyperparameter combinations and randomly select 10
param_combinations = list(product(learning_rates, weight_decays, epochs_list))
random.shuffle(param_combinations)
hyperparam_trials = param_combinations[:10]

# Run randomized search
best_model = None
best_acc = 0

for i, (lr, wd, epochs) in enumerate(hyperparam_trials):
    print(f"\n=== Trial {i+1}/10: LR={lr}, WD={wd}, Epochs={epochs} ===")

    model = get_model()
    model = model.to(device)
    
    # Use an optimizer like Adam or SGD (adjust based on your requirement)
    optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=0.9, weight_decay=wd)
    
    # Train the model (assuming you have a function to handle training)
    train(model, train_loader, val_loader, criterion, optimizer, epochs)

    hyperparams = {
        "batch_size": batch_size,
        "learning_rate": lr,
        "epochs": epochs,
        "optimizer": optimizer,
        "model": model.__class__.__name__,
    }
    
    val_acc = evaluate_model(model, val_loader, device, hyperparams=hyperparams)
    if val_acc > best_acc:
        best_acc = val_acc
        best_model = model
        torch.save(model.state_dict(), 'best_model.pt')
    
print("\nBest validation accuracy:", best_acc)
# Out:
# === Trial 1/10: LR=0.0005, WD=1e-08, Epochs=20 ===
# Epoch [1/20], train loss: 0.2183, train acc: 0.9139, val loss: 0.1386, val acc: 0.9450
# Epoch [2/20], train loss: 0.1101, train acc: 0.9583, val loss: 0.1166, val acc: 0.9575
# Epoch [3/20], train loss: 0.0671, train acc: 0.9754, val loss: 0.1696, val acc: 0.9425
# Epoch [4/20], train loss: 0.0396, train acc: 0.9865, val loss: 0.1214, val acc: 0.9589
# Epoch [5/20], train loss: 0.0208, train acc: 0.9936, val loss: 0.1339, val acc: 0.9637
# Epoch [6/20], train loss: 0.0128, train acc: 0.9966, val loss: 0.1180, val acc: 0.9633
# Epoch [7/20], train loss: 0.0083, train acc: 0.9976, val loss: 0.1351, val acc: 0.9614
# Epoch [8/20], train loss: 0.0087, train acc: 0.9973, val loss: 0.1309, val acc: 0.9633
# Epoch [9/20], train loss: 0.0069, train acc: 0.9981, val loss: 0.1279, val acc: 0.9653
# Epoch [10/20], train loss: 0.0040, train acc: 0.9993, val loss: 0.2126, val acc: 0.9563
# Epoch [11/20], train loss: 0.0032, train acc: 0.9994, val loss: 0.1304, val acc: 0.9667
# Epoch [12/20], train loss: 0.0028, train acc: 0.9993, val loss: 0.1375, val acc: 0.9676
# Epoch [13/20], train loss: 0.0055, train acc: 0.9984, val loss: 0.1484, val acc: 0.9579
# Epoch [14/20], train loss: 0.0033, train acc: 0.9989, val loss: 0.1360, val acc: 0.9676
# Epoch [15/20], train loss: 0.0023, train acc: 0.9994, val loss: 0.1513, val acc: 0.9661
# Epoch [16/20], train loss: 0.0014, train acc: 0.9998, val loss: 0.1807, val acc: 0.9612
# Epoch [17/20], train loss: 0.0022, train acc: 0.9996, val loss: 0.1405, val acc: 0.9657
# Epoch [18/20], train loss: 0.0017, train acc: 0.9996, val loss: 0.1333, val acc: 0.9682
# Epoch [19/20], train loss: 0.0012, train acc: 0.9999, val loss: 0.1489, val acc: 0.9692
# Epoch [20/20], train loss: 0.0014, train acc: 0.9996, val loss: 0.1532, val acc: 0.9672
# ===== Evaluation at 2025-05-23 13:22:53 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.0005
# epochs: 20
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.0005
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-08
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.9039
# human: 0.9861
#
# Precision, Recall, F1:
# ai → Precision: 0.9513, Recall: 0.9039, F1: 0.9270
# human → Precision: 0.9716, Recall: 0.9861, F1: 0.9788
#
# False Positive Rate:
# ai: 0.0139
# human: 0.0961
#
# Overall Accuracy: 0.9672
# Average Inference Time per Sample: 0.010767 seconds
# ========================================
#
#
#
# === Trial 2/10: LR=0.0005, WD=1e-06, Epochs=5 ===
# Epoch [1/5], train loss: 0.2129, train acc: 0.9176, val loss: 0.1266, val acc: 0.9544
# Epoch [2/5], train loss: 0.1044, train acc: 0.9608, val loss: 0.1135, val acc: 0.9561
# Epoch [3/5], train loss: 0.0648, train acc: 0.9762, val loss: 0.0998, val acc: 0.9608
# Epoch [4/5], train loss: 0.0309, train acc: 0.9905, val loss: 0.1148, val acc: 0.9598
# Epoch [5/5], train loss: 0.0215, train acc: 0.9932, val loss: 0.1155, val acc: 0.9589
# ===== Evaluation at 2025-05-23 13:50:06 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.0005
# epochs: 5
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.0005
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-06
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.8959
# human: 0.9778
#
# Precision, Recall, F1:
# ai → Precision: 0.9239, Recall: 0.8959, F1: 0.9097
# human → Precision: 0.9691, Recall: 0.9778, F1: 0.9734
#
# False Positive Rate:
# ai: 0.0222
# human: 0.1041
#
# Overall Accuracy: 0.9589
# Average Inference Time per Sample: 0.010754 seconds
# ========================================
#
#
#
# === Trial 3/10: LR=0.0005, WD=1e-06, Epochs=10 ===
# Epoch [1/10], train loss: 0.2035, train acc: 0.9196, val loss: 0.1367, val acc: 0.9472
# Epoch [2/10], train loss: 0.1050, train acc: 0.9609, val loss: 0.1140, val acc: 0.9552
# Epoch [3/10], train loss: 0.0641, train acc: 0.9764, val loss: 0.1249, val acc: 0.9573
# Epoch [4/10], train loss: 0.0356, train acc: 0.9875, val loss: 0.1276, val acc: 0.9516
# Epoch [5/10], train loss: 0.0195, train acc: 0.9939, val loss: 0.1212, val acc: 0.9596
# Epoch [6/10], train loss: 0.0132, train acc: 0.9963, val loss: 0.1276, val acc: 0.9653
# Epoch [7/10], train loss: 0.0087, train acc: 0.9979, val loss: 0.1302, val acc: 0.9633
# Epoch [8/10], train loss: 0.0067, train acc: 0.9982, val loss: 0.1311, val acc: 0.9651
# Epoch [9/10], train loss: 0.0040, train acc: 0.9993, val loss: 0.1210, val acc: 0.9651
# Epoch [10/10], train loss: 0.0030, train acc: 0.9994, val loss: 0.1354, val acc: 0.9690
# ===== Evaluation at 2025-05-23 14:43:40 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.0005
# epochs: 10
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.0005
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-06
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.9101
# human: 0.9867
#
# Precision, Recall, F1:
# ai → Precision: 0.9534, Recall: 0.9101, F1: 0.9313
# human → Precision: 0.9734, Recall: 0.9867, F1: 0.9800
#
# False Positive Rate:
# ai: 0.0133
# human: 0.0899
#
# Overall Accuracy: 0.9690
# Average Inference Time per Sample: 0.010755 seconds
# ========================================
#
#
#
# === Trial 4/10: LR=0.0001, WD=1e-08, Epochs=20 ===
# Epoch [1/20], train loss: 0.2950, train acc: 0.8809, val loss: 0.2071, val acc: 0.9191
# Epoch [2/20], train loss: 0.1775, train acc: 0.9331, val loss: 0.1696, val acc: 0.9347
# Epoch [3/20], train loss: 0.1450, train acc: 0.9443, val loss: 0.1571, val acc: 0.9398
# Epoch [4/20], train loss: 0.1192, train acc: 0.9564, val loss: 0.1390, val acc: 0.9487
# Epoch [5/20], train loss: 0.0989, train acc: 0.9644, val loss: 0.1345, val acc: 0.9487
# Epoch [6/20], train loss: 0.0805, train acc: 0.9708, val loss: 0.1321, val acc: 0.9503
# Epoch [7/20], train loss: 0.0650, train acc: 0.9783, val loss: 0.1264, val acc: 0.9518
# Epoch [8/20], train loss: 0.0516, train acc: 0.9836, val loss: 0.1383, val acc: 0.9516
# Epoch [9/20], train loss: 0.0421, train acc: 0.9862, val loss: 0.1274, val acc: 0.9544
# Epoch [10/20], train loss: 0.0329, train acc: 0.9902, val loss: 0.1308, val acc: 0.9532
# Epoch [11/20], train loss: 0.0256, train acc: 0.9930, val loss: 0.1313, val acc: 0.9561
# Epoch [12/20], train loss: 0.0192, train acc: 0.9957, val loss: 0.1382, val acc: 0.9573
# Epoch [13/20], train loss: 0.0180, train acc: 0.9961, val loss: 0.1432, val acc: 0.9565
# Epoch [14/20], train loss: 0.0129, train acc: 0.9976, val loss: 0.1389, val acc: 0.9573
# Epoch [15/20], train loss: 0.0121, train acc: 0.9972, val loss: 0.1512, val acc: 0.9573
# Epoch [16/20], train loss: 0.0099, train acc: 0.9982, val loss: 0.1475, val acc: 0.9542
# Epoch [17/20], train loss: 0.0107, train acc: 0.9978, val loss: 0.1406, val acc: 0.9579
# Epoch [18/20], train loss: 0.0079, train acc: 0.9989, val loss: 0.1478, val acc: 0.9587
# Epoch [19/20], train loss: 0.0065, train acc: 0.9992, val loss: 0.1518, val acc: 0.9585
# Epoch [20/20], train loss: 0.0056, train acc: 0.9992, val loss: 0.1601, val acc: 0.9594
# ===== Evaluation at 2025-05-23 16:37:42 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.0001
# epochs: 20
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.0001
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-08
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.8710
# human: 0.9859
#
# Precision, Recall, F1:
# ai → Precision: 0.9486, Recall: 0.8710, F1: 0.9082
# human → Precision: 0.9622, Recall: 0.9859, F1: 0.9739
#
# False Positive Rate:
# ai: 0.0141
# human: 0.1290
#
# Overall Accuracy: 0.9594
# Average Inference Time per Sample: 0.013774 seconds
# ========================================
#
#
#
# === Trial 5/10: LR=0.0001, WD=1e-07, Epochs=5 ===
# Epoch [1/5], train loss: 0.3018, train acc: 0.8806, val loss: 0.2116, val acc: 0.9152
# Epoch [2/5], train loss: 0.1833, train acc: 0.9321, val loss: 0.1700, val acc: 0.9339
# Epoch [3/5], train loss: 0.1493, train acc: 0.9425, val loss: 0.1490, val acc: 0.9409
# Epoch [4/5], train loss: 0.1234, train acc: 0.9536, val loss: 0.1388, val acc: 0.9454
# Epoch [5/5], train loss: 0.1047, train acc: 0.9615, val loss: 0.1399, val acc: 0.9460
# ===== Evaluation at 2025-05-23 17:08:26 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.0001
# epochs: 5
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.0001
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-07
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.8078
# human: 0.9875
#
# Precision, Recall, F1:
# ai → Precision: 0.9508, Recall: 0.8078, F1: 0.8735
# human → Precision: 0.9448, Recall: 0.9875, F1: 0.9657
#
# False Positive Rate:
# ai: 0.0125
# human: 0.1922
#
# Overall Accuracy: 0.9460
# Average Inference Time per Sample: 0.012145 seconds
# ========================================
#
#
#
# === Trial 6/10: LR=0.001, WD=1e-07, Epochs=10 ===
# Epoch [1/10], train loss: 0.1936, train acc: 0.9246, val loss: 0.1090, val acc: 0.9577
# Epoch [2/10], train loss: 0.0899, train acc: 0.9670, val loss: 0.0969, val acc: 0.9639
# Epoch [3/10], train loss: 0.0506, train acc: 0.9824, val loss: 0.1454, val acc: 0.9458
# Epoch [4/10], train loss: 0.0265, train acc: 0.9904, val loss: 0.1079, val acc: 0.9641
# Epoch [5/10], train loss: 0.0180, train acc: 0.9934, val loss: 0.1202, val acc: 0.9616
# Epoch [6/10], train loss: 0.0139, train acc: 0.9952, val loss: 0.1093, val acc: 0.9713
# Epoch [7/10], train loss: 0.0109, train acc: 0.9965, val loss: 0.1267, val acc: 0.9686
# Epoch [8/10], train loss: 0.0085, train acc: 0.9974, val loss: 0.1260, val acc: 0.9682
# Epoch [9/10], train loss: 0.0051, train acc: 0.9985, val loss: 0.1494, val acc: 0.9672
# Epoch [10/10], train loss: 0.0057, train acc: 0.9982, val loss: 0.1297, val acc: 0.9702
# ===== Evaluation at 2025-05-23 18:10:09 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.001
# epochs: 10
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-07
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.9093
# human: 0.9885
#
# Precision, Recall, F1:
# ai → Precision: 0.9596, Recall: 0.9093, F1: 0.9338
# human → Precision: 0.9732, Recall: 0.9885, F1: 0.9808
#
# False Positive Rate:
# ai: 0.0115
# human: 0.0907
#
# Overall Accuracy: 0.9702
# Average Inference Time per Sample: 0.016758 seconds
# ========================================
#
#
#
# === Trial 7/10: LR=0.0005, WD=1e-07, Epochs=5 ===
# Epoch [1/5], train loss: 0.2045, train acc: 0.9189, val loss: 0.1343, val acc: 0.9493
# Epoch [2/5], train loss: 0.1065, train acc: 0.9600, val loss: 0.1227, val acc: 0.9565
# Epoch [3/5], train loss: 0.0626, train acc: 0.9777, val loss: 0.1145, val acc: 0.9559
# Epoch [4/5], train loss: 0.0341, train acc: 0.9896, val loss: 0.1272, val acc: 0.9579
# Epoch [5/5], train loss: 0.0195, train acc: 0.9945, val loss: 0.1310, val acc: 0.9614
# ===== Evaluation at 2025-05-23 18:43:33 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.0005
# epochs: 5
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.0005
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-07
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.8710
# human: 0.9885
#
# Precision, Recall, F1:
# ai → Precision: 0.9579, Recall: 0.8710, F1: 0.9124
# human → Precision: 0.9623, Recall: 0.9885, F1: 0.9753
#
# False Positive Rate:
# ai: 0.0115
# human: 0.1290
#
# Overall Accuracy: 0.9614
# Average Inference Time per Sample: 0.012608 seconds
# ========================================
#
#
#
# === Trial 8/10: LR=0.0001, WD=1e-06, Epochs=20 ===
# Epoch [1/20], train loss: 0.2894, train acc: 0.8872, val loss: 0.2026, val acc: 0.9232
# Epoch [2/20], train loss: 0.1793, train acc: 0.9311, val loss: 0.1667, val acc: 0.9347
# Epoch [3/20], train loss: 0.1430, train acc: 0.9459, val loss: 0.1508, val acc: 0.9403
# Epoch [4/20], train loss: 0.1212, train acc: 0.9560, val loss: 0.1396, val acc: 0.9444
# Epoch [5/20], train loss: 0.0983, train acc: 0.9650, val loss: 0.1364, val acc: 0.9466
# Epoch [6/20], train loss: 0.0786, train acc: 0.9714, val loss: 0.1296, val acc: 0.9505
# Epoch [7/20], train loss: 0.0655, train acc: 0.9767, val loss: 0.1256, val acc: 0.9532
# Epoch [8/20], train loss: 0.0506, train acc: 0.9838, val loss: 0.1276, val acc: 0.9534
# Epoch [9/20], train loss: 0.0428, train acc: 0.9868, val loss: 0.1252, val acc: 0.9559
# Epoch [10/20], train loss: 0.0322, train acc: 0.9910, val loss: 0.1283, val acc: 0.9534
# Epoch [11/20], train loss: 0.0263, train acc: 0.9932, val loss: 0.1373, val acc: 0.9550
# Epoch [12/20], train loss: 0.0201, train acc: 0.9952, val loss: 0.1319, val acc: 0.9552
# Epoch [13/20], train loss: 0.0162, train acc: 0.9960, val loss: 0.1317, val acc: 0.9550
# Epoch [14/20], train loss: 0.0135, train acc: 0.9970, val loss: 0.1396, val acc: 0.9550
# Epoch [15/20], train loss: 0.0111, train acc: 0.9982, val loss: 0.1387, val acc: 0.9565
# Epoch [16/20], train loss: 0.0105, train acc: 0.9980, val loss: 0.1517, val acc: 0.9565
# Epoch [17/20], train loss: 0.0082, train acc: 0.9986, val loss: 0.1408, val acc: 0.9552
# Epoch [18/20], train loss: 0.0076, train acc: 0.9989, val loss: 0.1501, val acc: 0.9555
# Epoch [19/20], train loss: 0.0071, train acc: 0.9989, val loss: 0.1520, val acc: 0.9561
# Epoch [20/20], train loss: 0.0056, train acc: 0.9992, val loss: 0.1543, val acc: 0.9550
# ===== Evaluation at 2025-05-23 20:43:21 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.0001
# epochs: 20
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.0001
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-06
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.8577
# human: 0.9843
#
# Precision, Recall, F1:
# ai → Precision: 0.9423, Recall: 0.8577, F1: 0.8980
# human → Precision: 0.9584, Recall: 0.9843, F1: 0.9712
#
# False Positive Rate:
# ai: 0.0157
# human: 0.1423
#
# Overall Accuracy: 0.9550
# Average Inference Time per Sample: 0.012146 seconds
# ========================================
#
#
#
# === Trial 9/10: LR=0.001, WD=1e-08, Epochs=20 ===
# Epoch [1/20], train loss: 0.1884, train acc: 0.9261, val loss: 0.1540, val acc: 0.9407
# Epoch [2/20], train loss: 0.0860, train acc: 0.9672, val loss: 0.1158, val acc: 0.9571
# Epoch [3/20], train loss: 0.0496, train acc: 0.9819, val loss: 0.1090, val acc: 0.9620
# Epoch [4/20], train loss: 0.0257, train acc: 0.9909, val loss: 0.1073, val acc: 0.9680
# Epoch [5/20], train loss: 0.0193, train acc: 0.9931, val loss: 0.1263, val acc: 0.9614
# Epoch [6/20], train loss: 0.0144, train acc: 0.9949, val loss: 0.1492, val acc: 0.9612
# Epoch [7/20], train loss: 0.0121, train acc: 0.9963, val loss: 0.1563, val acc: 0.9610
# Epoch [8/20], train loss: 0.0073, train acc: 0.9977, val loss: 0.1186, val acc: 0.9702
# Epoch [9/20], train loss: 0.0032, train acc: 0.9990, val loss: 0.1343, val acc: 0.9682
# Epoch [10/20], train loss: 0.0062, train acc: 0.9981, val loss: 0.1326, val acc: 0.9708
# Epoch [11/20], train loss: 0.0041, train acc: 0.9987, val loss: 0.1174, val acc: 0.9721
# Epoch [12/20], train loss: 0.0035, train acc: 0.9989, val loss: 0.1315, val acc: 0.9706
# Epoch [13/20], train loss: 0.0020, train acc: 0.9994, val loss: 0.1245, val acc: 0.9721
# Epoch [14/20], train loss: 0.0010, train acc: 0.9998, val loss: 0.1319, val acc: 0.9727
# Epoch [15/20], train loss: 0.0012, train acc: 0.9997, val loss: 0.1271, val acc: 0.9708
# Epoch [16/20], train loss: 0.0011, train acc: 0.9997, val loss: 0.1339, val acc: 0.9715
# Epoch [17/20], train loss: 0.0017, train acc: 0.9995, val loss: 0.1498, val acc: 0.9635
# Epoch [18/20], train loss: 0.0036, train acc: 0.9989, val loss: 0.1320, val acc: 0.9649
# Epoch [19/20], train loss: 0.0043, train acc: 0.9989, val loss: 0.1513, val acc: 0.9715
# Epoch [20/20], train loss: 0.0012, train acc: 0.9999, val loss: 0.1333, val acc: 0.9708
# ===== Evaluation at 2025-05-23 22:36:17 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.001
# epochs: 20
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-08
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.9279
# human: 0.9837
#
# Precision, Recall, F1:
# ai → Precision: 0.9447, Recall: 0.9279, F1: 0.9363
# human → Precision: 0.9785, Recall: 0.9837, F1: 0.9811
#
# False Positive Rate:
# ai: 0.0163
# human: 0.0721
#
# Overall Accuracy: 0.9708
# Average Inference Time per Sample: 0.012249 seconds
# ========================================
#
#
#
# === Trial 10/10: LR=0.001, WD=1e-07, Epochs=5 ===
# Epoch [1/5], train loss: 0.1872, train acc: 0.9271, val loss: 0.1352, val acc: 0.9497
# Epoch [2/5], train loss: 0.0894, train acc: 0.9659, val loss: 0.0933, val acc: 0.9659
# Epoch [3/5], train loss: 0.0517, train acc: 0.9810, val loss: 0.1069, val acc: 0.9606
# Epoch [4/5], train loss: 0.0274, train acc: 0.9910, val loss: 0.1431, val acc: 0.9565
# Epoch [5/5], train loss: 0.0189, train acc: 0.9937, val loss: 0.1440, val acc: 0.9573
# ===== Evaluation at 2025-05-23 23:05:13 =====
#
# Hyperparameters:
# batch_size: 32
# learning_rate: 0.001
# epochs: 5
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 1e-07
# )
# model: ResNet
#
# Accuracy per class:
# ai: 0.8728
# human: 0.9827
#
# Precision, Recall, F1:
# ai → Precision: 0.9379, Recall: 0.8728, F1: 0.9041
# human → Precision: 0.9626, Recall: 0.9827, F1: 0.9725
#
# False Positive Rate:
# ai: 0.0173
# human: 0.1272
#
# Overall Accuracy: 0.9573
# Average Inference Time per Sample: 0.012230 seconds
# ========================================
#
#
#
# Best validation accuracy: 0.9708478751796346

# %%
model = get_model()
model.load_state_dict(torch.load("best_model.pt", map_location=device))
model.to(device)
model.eval()
results = []

for batch in tqdm(ai_aug_test_loader):
    inputs, labels, filenames = batch  # Unpack the filename from the dataset
    inputs = inputs.to(device)
    labels = labels.to(device)

    with torch.no_grad():
        outputs = model(inputs)
        probs = F.softmax(outputs, dim=1)

        for i in range(len(filenames)):
            results.append({
                "filename": filenames[i],  # Use filename directly from dataset
                "prob_ai": probs[i][0].item(),
                "prob_human": probs[i][1].item(),
                "true_label": labels[i].item(),
                "pred_label": torch.argmax(probs[i]).item()
            })

# Convert the results to a DataFrame
df = pd.DataFrame(results)

# Save to CSV
df.to_csv("best_mel-spec_ai_aug_test_predictions.csv", index=False)

# Preview results
print(df.head())
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 443/443 [21:07<00:00,  2.86s/it]
#                                           filename   prob_ai  prob_human  \
# 0  S3587RN_segment_2_stretched-Mel_Spectrogram.png  0.961807    0.038193
# 1    S3524RN_segment_2_shifted-Mel_Spectrogram.png  0.001341    0.998659
# 2    S2313RN_segment_1_shifted-Mel_Spectrogram.png  0.001216    0.998784
# 3  S5015RN_segment_2_stretched-Mel_Spectrogram.png  0.000897    0.999103
# 4  U1116RN_segment_1_stretched-Mel_Spectrogram.png  0.000011    0.999989
#
#    true_label  pred_label
# 0           1           0
# 1           1           1
# 2           1           1
# 3           1           1
# 4           1           1

# %%
# Load the CSV
df = pd.read_csv("best_mel-spec_ai_aug_test_predictions.csv")  # Replace with your actual file path

# Total number of rows (i.e. total number of samples/files)
total = len(df)

# Count where prediction is correct
correct = (df["true_label"] == df["pred_label"]).sum()

print(f"Correct predictions: {correct}/{total} ({correct/total:.2%})")
# Out:
# Correct predictions: 12964/14149 (91.62%)
